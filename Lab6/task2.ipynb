# %%
from src.CSPclass import *
from src.agents import *
from src.utils import *
from src.algorithms import *

# %%
var1=list("ABCDEFGHI")
var2=range(1,10)

vars=set()

for letter in var1:
    for number in var2:
      vars.add(letter+str(number))

# %%
sudokuNeighbors={}

for letter in var1:
    for number in var2:
      sudokuNeighbors[letter+str(number)]=[]

# %%
row_groups = [
    ['A', 'B', 'C'], # top
    ['D', 'E', 'F'], # middle
    ['G', 'H', 'I']  # bottom
]

col_groups = [
    ['1', '2', '3'], # left
    ['4', '5', '6'], # middle
    ['7', '8', '9']  # right
]

asterisk_group = [
    ['B5','C3','C7','E2','E5','E8','G3','G7','H5']
]

for key1 in sudokuNeighbors.keys():
  for key2 in sudokuNeighbors.keys():
    if key1 != key2:
      if key1[0] == key2[0]:
        if key2 not in sudokuNeighbors[key1]:
          sudokuNeighbors[key1].append(key2) 
      if key1[1] == key2[1]:
        if key2 not in sudokuNeighbors[key1]:
          sudokuNeighbors[key1].append(key2)
      for row in row_groups:
        if key1[0] in row and key2[0] in row:
          for col in col_groups:
            if key1[1] in col and key2[1] in col:
              if key2 not in sudokuNeighbors[key1]:
                sudokuNeighbors[key1].append(key2)
      for asterisk in asterisk_group:
        if key1 in asterisk and key2 in asterisk:
          if key2 not in sudokuNeighbors[key1]:
            sudokuNeighbors[key1].append(key2)

# %%
filled = {
    'A2': 1, 'A8': 6,
    'B1': 3, 'B3': 9, 'B7': 1, 'B9': 5,
    'C2': 8, 'C4': 3, 'C6': 5, 'C8': 7,
    'D3': 2, 'D5': 7, 'D7': 8,
    'E4': 6, 'E6': 8,
    'F3': 8, 'F5': 9, 'F7': 2,
    'G2': 2, 'G4': 4, 'G6': 1, 'G8': 9,
    'H1': 9, 'H3': 4, 'H7': 6, 'H9': 1,
    'I2': 3, 'I8': 8
}

# %%
sudokuDomains={var:[filled[var]] if var in filled else [ch for ch in range(1,10)] for var in sudokuNeighbors.keys()}

# %%
sudokuConstraints1 = lambda X, x, Y, y: x!=y

# %%
basicSudokuCSP=CSP(variables=sudokuNeighbors.keys(),neighbors=sudokuNeighbors, domains=sudokuDomains, constraints=sudokuConstraints1)

# %%
AC3(basicSudokuCSP)
# Out:
# Initial queue:
# ('A1', 'A2') ('A1', 'A3') ('A1', 'A4') ('A1', 'A5') ('A1', 'A6') ('A1', 'A7') ('A1', 'A8') ('A1', 'A9') ('A1', 'B1') ('A1', 'B2') ('A1', 'B3') ('A1', 'C1') ('A1', 'C2') ('A1', 'C3') ('A1', 'D1') ('A1', 'E1') ('A1', 'F1') ('A1', 'G1') ('A1', 'H1') ('A1', 'I1')
# ('A2', 'A1') ('A2', 'A3') ('A2', 'A4') ('A2', 'A5') ('A2', 'A6') ('A2', 'A7') ('A2', 'A8') ('A2', 'A9') ('A2', 'B1') ('A2', 'B2') ('A2', 'B3') ('A2', 'C1') ('A2', 'C2') ('A2', 'C3') ('A2', 'D2') ('A2', 'E2') ('A2', 'F2') ('A2', 'G2') ('A2', 'H2') ('A2', 'I2')
# The val 8 was deleted from A1 domain
# Arc ('A1', 'C3') is cheking
# Arc ('A1', 'D1') is cheking
# Arc ('A1', 'E1') is cheking
# Arc ('A1', 'F1') is cheking
# Arc ('A1', 'G1') is cheking
# Arc ('A1', 'H1') is cheking
# Arc ('A1', 'I1') is cheking
# Arc ('A2', 'A1') is cheking
# Arc ('A2', 'A3') is cheking
# Arc ('A2', 'A4') is cheking
# Arc ('A2', 'A5') is cheking
# Arc ('A2', 'A6') is cheking
# Arc ('A2', 'A7') is cheking
# Arc ('A2', 'A8') is cheking
# Arc ('A2', 'A9') is cheking
# Arc ('A2', 'B1') is cheking
# Arc ('A2', 'B2') is cheking
# Arc ('A2', 'B3') is cheking
# Arc ('A2', 'C1') is cheking
# Arc ('A2', 'C2') is cheking
# Arc ('A2', 'C3') is cheking
# Arc ('A2', 'D2') is cheking
# Arc ('A2', 'E2') is cheking
# Arc ('A2', 'F2') is cheking
# Arc ('A2', 'G2') is cheking
# Arc ('A2', 'H2') is cheking
# Arc ('A2', 'I2') is cheking
# Arc ('A3', 'A1') is cheking
# Arc ('A3', 'A2') is cheking
# The val 1 was deleted from A3 domain
# Arc ('A3', 'A4') is cheking
# Arc ('A3', 'A5') is cheking
# Arc ('A3', 'A6') is cheking
# Arc ('A3', 'A7') is cheking
# Arc ('A3', 'A8') is cheking
# The val 6 was deleted from A3 domain
# Arc ('A3', 'A9') is cheking
# Arc ('A3', 'B1') is cheking
# The val 3 was deleted from A3 domain
# Arc ('A3', 'B2') is cheking
# Arc ('A3', 'B3') is cheking
# The val 9 was deleted from A3 domain
# Arc ('A3', 'C1') is cheking
# Arc ('A3', 'C2') is cheking
# The val 8 was deleted from A3 domain
# Arc ('A3', 'C3') is cheking
# Arc ('A3', 'D3') is cheking
# The val 2 was deleted from A3 domain
# Arc ('A3', 'E3') is cheking
# Arc ('A3', 'F3') is cheking
# Arc ('A3', 'G3') is cheking
# Arc ('A3', 'H3') is cheking
# The val 4 was deleted from A3 domain
# Arc ('A3', 'I3') is cheking
# Arc ('A4', 'A1') is cheking
# Arc ('A4', 'A2') is cheking
# The val 1 was deleted from A4 domain
# Arc ('A4', 'A3') is cheking
# Arc ('A4', 'A5') is cheking
# Arc ('A4', 'A6') is cheking
# Arc ('A4', 'A7') is cheking
# Arc ('A4', 'A8') is cheking
# The val 6 was deleted from A4 domain
# Arc ('A4', 'A9') is cheking
# Arc ('A4', 'B4') is cheking
# Arc ('A4', 'B5') is cheking
# Arc ('A4', 'B6') is cheking
# Arc ('A4', 'C4') is cheking
# The val 3 was deleted from A4 domain
# Arc ('A4', 'C5') is cheking
# Arc ('A4', 'C6') is cheking
# The val 5 was deleted from A4 domain
# Arc ('A4', 'D4') is cheking
# Arc ('A4', 'E4') is cheking
# Arc ('A4', 'F4') is cheking
# Arc ('A4', 'G4') is cheking
# The val 4 was deleted from A4 domain
# Arc ('A4', 'H4') is cheking
# Arc ('A4', 'I4') is cheking
# Arc ('A5', 'A1') is cheking
# Arc ('A5', 'A2') is cheking
# The val 1 was deleted from A5 domain
# Arc ('A5', 'A3') is cheking
# Arc ('A5', 'A4') is cheking
# Arc ('A5', 'A6') is cheking
# Arc ('A5', 'A7') is cheking
# Arc ('A5', 'A8') is cheking
# The val 6 was deleted from A5 domain
# Arc ('A5', 'A9') is cheking
# Arc ('A5', 'B4') is cheking
# Arc ('A5', 'B5') is cheking
# Arc ('A5', 'B6') is cheking
# Arc ('A5', 'C4') is cheking
# The val 3 was deleted from A5 domain
# Arc ('A5', 'C5') is cheking
# Arc ('A5', 'C6') is cheking
# The val 5 was deleted from A5 domain
# Arc ('A5', 'D5') is cheking
# The val 7 was deleted from A5 domain
# Arc ('A5', 'E5') is cheking
# Arc ('A5', 'F5') is cheking
# The val 9 was deleted from A5 domain
# Arc ('A5', 'G5') is cheking
# Arc ('A5', 'H5') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('A6', 'A1') is cheking
# Arc ('A6', 'A2') is cheking
# The val 1 was deleted from A6 domain
# Arc ('A6', 'A3') is cheking
# Arc ('A6', 'A4') is cheking
# Arc ('A6', 'A5') is cheking
# Arc ('A6', 'A7') is cheking
# Arc ('A6', 'A8') is cheking
# The val 6 was deleted from A6 domain
# Arc ('A6', 'A9') is cheking
# Arc ('A6', 'B4') is cheking
# Arc ('A6', 'B5') is cheking
# Arc ('A6', 'B6') is cheking
# Arc ('A6', 'C4') is cheking
# The val 3 was deleted from A6 domain
# Arc ('A6', 'C5') is cheking
# Arc ('A6', 'C6') is cheking
# The val 5 was deleted from A6 domain
# Arc ('A6', 'D6') is cheking
# Arc ('A6', 'E6') is cheking
# The val 8 was deleted from A6 domain
# Arc ('A6', 'F6') is cheking
# Arc ('A6', 'G6') is cheking
# Arc ('A6', 'H6') is cheking
# Arc ('A6', 'I6') is cheking
# Arc ('A7', 'A1') is cheking
# Arc ('A7', 'A2') is cheking
# The val 1 was deleted from A7 domain
# Arc ('A7', 'A3') is cheking
# Arc ('A7', 'A4') is cheking
# Arc ('A7', 'A5') is cheking
# Arc ('A7', 'A6') is cheking
# Arc ('A7', 'A8') is cheking
# The val 6 was deleted from A7 domain
# Arc ('A7', 'A9') is cheking
# Arc ('A7', 'B7') is cheking
# Arc ('A7', 'B8') is cheking
# Arc ('A7', 'B9') is cheking
# The val 5 was deleted from A7 domain
# Arc ('A7', 'C7') is cheking
# Arc ('A7', 'C8') is cheking
# The val 7 was deleted from A7 domain
# Arc ('A7', 'C9') is cheking
# Arc ('A7', 'D7') is cheking
# The val 8 was deleted from A7 domain
# Arc ('A7', 'E7') is cheking
# Arc ('A7', 'F7') is cheking
# The val 2 was deleted from A7 domain
# Arc ('A7', 'G7') is cheking
# Arc ('A7', 'H7') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('A8', 'A1') is cheking
# Arc ('A8', 'A2') is cheking
# Arc ('A8', 'A3') is cheking
# Arc ('A8', 'A4') is cheking
# Arc ('A8', 'A5') is cheking
# Arc ('A8', 'A6') is cheking
# Arc ('A8', 'A7') is cheking
# Arc ('A8', 'A9') is cheking
# Arc ('A8', 'B7') is cheking
# Arc ('A8', 'B8') is cheking
# Arc ('A8', 'B9') is cheking
# Arc ('A8', 'C7') is cheking
# Arc ('A8', 'C8') is cheking
# Arc ('A8', 'C9') is cheking
# Arc ('A8', 'D8') is cheking
# Arc ('A8', 'E8') is cheking
# Arc ('A8', 'F8') is cheking
# Arc ('A8', 'G8') is cheking
# Arc ('A8', 'H8') is cheking
# Arc ('A8', 'I8') is cheking
# Arc ('A9', 'A1') is cheking
# Arc ('A9', 'A2') is cheking
# The val 1 was deleted from A9 domain
# Arc ('A9', 'A3') is cheking
# Arc ('A9', 'A4') is cheking
# Arc ('A9', 'A5') is cheking
# Arc ('A9', 'A6') is cheking
# Arc ('A9', 'A7') is cheking
# Arc ('A9', 'A8') is cheking
# The val 6 was deleted from A9 domain
# Arc ('A9', 'B7') is cheking
# Arc ('A9', 'B8') is cheking
# Arc ('A9', 'B9') is cheking
# The val 5 was deleted from A9 domain
# Arc ('A9', 'C7') is cheking
# Arc ('A9', 'C8') is cheking
# The val 7 was deleted from A9 domain
# Arc ('A9', 'C9') is cheking
# Arc ('A9', 'D9') is cheking
# Arc ('A9', 'E9') is cheking
# Arc ('A9', 'F9') is cheking
# Arc ('A9', 'G9') is cheking
# Arc ('A9', 'H9') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('B1', 'A1') is cheking
# Arc ('B1', 'A2') is cheking
# Arc ('B1', 'A3') is cheking
# Arc ('B1', 'B2') is cheking
# Arc ('B1', 'B3') is cheking
# Arc ('B1', 'B4') is cheking
# Arc ('B1', 'B5') is cheking
# Arc ('B1', 'B6') is cheking
# Arc ('B1', 'B7') is cheking
# Arc ('B1', 'B8') is cheking
# Arc ('B1', 'B9') is cheking
# Arc ('B1', 'C1') is cheking
# Arc ('B1', 'C2') is cheking
# Arc ('B1', 'C3') is cheking
# Arc ('B1', 'D1') is cheking
# Arc ('B1', 'E1') is cheking
# Arc ('B1', 'F1') is cheking
# Arc ('B1', 'G1') is cheking
# Arc ('B1', 'H1') is cheking
# Arc ('B1', 'I1') is cheking
# Arc ('B2', 'A1') is cheking
# Arc ('B2', 'A2') is cheking
# The val 1 was deleted from B2 domain
# Arc ('B2', 'A3') is cheking
# Arc ('B2', 'B1') is cheking
# The val 3 was deleted from B2 domain
# Arc ('B2', 'B3') is cheking
# The val 9 was deleted from B2 domain
# Arc ('B2', 'B4') is cheking
# Arc ('B2', 'B5') is cheking
# Arc ('B2', 'B6') is cheking
# Arc ('B2', 'B7') is cheking
# Arc ('B2', 'B8') is cheking
# Arc ('B2', 'B9') is cheking
# The val 5 was deleted from B2 domain
# Arc ('B2', 'C1') is cheking
# Arc ('B2', 'C2') is cheking
# The val 8 was deleted from B2 domain
# Arc ('B2', 'C3') is cheking
# Arc ('B2', 'D2') is cheking
# Arc ('B2', 'E2') is cheking
# Arc ('B2', 'F2') is cheking
# Arc ('B2', 'G2') is cheking
# The val 2 was deleted from B2 domain
# Arc ('B2', 'H2') is cheking
# Arc ('B2', 'I2') is cheking
# Arc ('B3', 'A1') is cheking
# Arc ('B3', 'A2') is cheking
# Arc ('B3', 'A3') is cheking
# Arc ('B3', 'B1') is cheking
# Arc ('B3', 'B2') is cheking
# Arc ('B3', 'B4') is cheking
# Arc ('B3', 'B5') is cheking
# Arc ('B3', 'B6') is cheking
# Arc ('B3', 'B7') is cheking
# Arc ('B3', 'B8') is cheking
# Arc ('B3', 'B9') is cheking
# Arc ('B3', 'C1') is cheking
# Arc ('B3', 'C2') is cheking
# Arc ('B3', 'C3') is cheking
# Arc ('B3', 'D3') is cheking
# Arc ('B3', 'E3') is cheking
# Arc ('B3', 'F3') is cheking
# Arc ('B3', 'G3') is cheking
# Arc ('B3', 'H3') is cheking
# Arc ('B3', 'I3') is cheking
# Arc ('B4', 'A4') is cheking
# Arc ('B4', 'A5') is cheking
# Arc ('B4', 'A6') is cheking
# Arc ('B4', 'B1') is cheking
# The val 3 was deleted from B4 domain
# Arc ('B4', 'B2') is cheking
# Arc ('B4', 'B3') is cheking
# The val 9 was deleted from B4 domain
# Arc ('B4', 'B5') is cheking
# Arc ('B4', 'B6') is cheking
# Arc ('B4', 'B7') is cheking
# The val 1 was deleted from B4 domain
# Arc ('B4', 'B8') is cheking
# Arc ('B4', 'B9') is cheking
# The val 5 was deleted from B4 domain
# Arc ('B4', 'C4') is cheking
# Arc ('B4', 'C5') is cheking
# Arc ('B4', 'C6') is cheking
# Arc ('B4', 'D4') is cheking
# Arc ('B4', 'E4') is cheking
# The val 6 was deleted from B4 domain
# Arc ('B4', 'F4') is cheking
# Arc ('B4', 'G4') is cheking
# The val 4 was deleted from B4 domain
# Arc ('B4', 'H4') is cheking
# Arc ('B4', 'I4') is cheking
# Arc ('B5', 'A4') is cheking
# Arc ('B5', 'A5') is cheking
# Arc ('B5', 'A6') is cheking
# Arc ('B5', 'B1') is cheking
# The val 3 was deleted from B5 domain
# Arc ('B5', 'B2') is cheking
# Arc ('B5', 'B3') is cheking
# The val 9 was deleted from B5 domain
# Arc ('B5', 'B4') is cheking
# Arc ('B5', 'B6') is cheking
# Arc ('B5', 'B7') is cheking
# The val 1 was deleted from B5 domain
# Arc ('B5', 'B8') is cheking
# Arc ('B5', 'B9') is cheking
# The val 5 was deleted from B5 domain
# Arc ('B5', 'C3') is cheking
# Arc ('B5', 'C4') is cheking
# Arc ('B5', 'C5') is cheking
# Arc ('B5', 'C6') is cheking
# Arc ('B5', 'C7') is cheking
# Arc ('B5', 'D5') is cheking
# The val 7 was deleted from B5 domain
# Arc ('B5', 'E2') is cheking
# Arc ('B5', 'E5') is cheking
# Arc ('B5', 'E8') is cheking
# Arc ('B5', 'F5') is cheking
# Arc ('B5', 'G3') is cheking
# Arc ('B5', 'G5') is cheking
# Arc ('B5', 'G7') is cheking
# Arc ('B5', 'H5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('B6', 'A4') is cheking
# Arc ('B6', 'A5') is cheking
# Arc ('B6', 'A6') is cheking
# Arc ('B6', 'B1') is cheking
# The val 3 was deleted from B6 domain
# Arc ('B6', 'B2') is cheking
# Arc ('B6', 'B3') is cheking
# The val 9 was deleted from B6 domain
# Arc ('B6', 'B4') is cheking
# Arc ('B6', 'B5') is cheking
# Arc ('B6', 'B7') is cheking
# The val 1 was deleted from B6 domain
# Arc ('B6', 'B8') is cheking
# Arc ('B6', 'B9') is cheking
# The val 5 was deleted from B6 domain
# Arc ('B6', 'C4') is cheking
# Arc ('B6', 'C5') is cheking
# Arc ('B6', 'C6') is cheking
# Arc ('B6', 'D6') is cheking
# Arc ('B6', 'E6') is cheking
# The val 8 was deleted from B6 domain
# Arc ('B6', 'F6') is cheking
# Arc ('B6', 'G6') is cheking
# Arc ('B6', 'H6') is cheking
# Arc ('B6', 'I6') is cheking
# Arc ('B7', 'A7') is cheking
# Arc ('B7', 'A8') is cheking
# Arc ('B7', 'A9') is cheking
# Arc ('B7', 'B1') is cheking
# Arc ('B7', 'B2') is cheking
# Arc ('B7', 'B3') is cheking
# Arc ('B7', 'B4') is cheking
# Arc ('B7', 'B5') is cheking
# Arc ('B7', 'B6') is cheking
# Arc ('B7', 'B8') is cheking
# Arc ('B7', 'B9') is cheking
# Arc ('B7', 'C7') is cheking
# Arc ('B7', 'C8') is cheking
# Arc ('B7', 'C9') is cheking
# Arc ('B7', 'D7') is cheking
# Arc ('B7', 'E7') is cheking
# Arc ('B7', 'F7') is cheking
# Arc ('B7', 'G7') is cheking
# Arc ('B7', 'H7') is cheking
# Arc ('B7', 'I7') is cheking
# Arc ('B8', 'A7') is cheking
# Arc ('B8', 'A8') is cheking
# The val 6 was deleted from B8 domain
# Arc ('B8', 'A9') is cheking
# Arc ('B8', 'B1') is cheking
# The val 3 was deleted from B8 domain
# Arc ('B8', 'B2') is cheking
# Arc ('B8', 'B3') is cheking
# The val 9 was deleted from B8 domain
# Arc ('B8', 'B4') is cheking
# Arc ('B8', 'B5') is cheking
# Arc ('B8', 'B6') is cheking
# Arc ('B8', 'B7') is cheking
# The val 1 was deleted from B8 domain
# Arc ('B8', 'B9') is cheking
# The val 5 was deleted from B8 domain
# Arc ('B8', 'C7') is cheking
# Arc ('B8', 'C8') is cheking
# The val 7 was deleted from B8 domain
# Arc ('B8', 'C9') is cheking
# Arc ('B8', 'D8') is cheking
# Arc ('B8', 'E8') is cheking
# Arc ('B8', 'F8') is cheking
# Arc ('B8', 'G8') is cheking
# Arc ('B8', 'H8') is cheking
# Arc ('B8', 'I8') is cheking
# The val 8 was deleted from B8 domain
# Arc ('B9', 'A7') is cheking
# Arc ('B9', 'A8') is cheking
# Arc ('B9', 'A9') is cheking
# Arc ('B9', 'B1') is cheking
# Arc ('B9', 'B2') is cheking
# Arc ('B9', 'B3') is cheking
# Arc ('B9', 'B4') is cheking
# Arc ('B9', 'B5') is cheking
# Arc ('B9', 'B6') is cheking
# Arc ('B9', 'B7') is cheking
# Arc ('B9', 'B8') is cheking
# Arc ('B9', 'C7') is cheking
# Arc ('B9', 'C8') is cheking
# Arc ('B9', 'C9') is cheking
# Arc ('B9', 'D9') is cheking
# Arc ('B9', 'E9') is cheking
# Arc ('B9', 'F9') is cheking
# Arc ('B9', 'G9') is cheking
# Arc ('B9', 'H9') is cheking
# Arc ('B9', 'I9') is cheking
# Arc ('C1', 'A1') is cheking
# Arc ('C1', 'A2') is cheking
# The val 1 was deleted from C1 domain
# Arc ('C1', 'A3') is cheking
# Arc ('C1', 'B1') is cheking
# The val 3 was deleted from C1 domain
# Arc ('C1', 'B2') is cheking
# Arc ('C1', 'B3') is cheking
# The val 9 was deleted from C1 domain
# Arc ('C1', 'C2') is cheking
# The val 8 was deleted from C1 domain
# Arc ('C1', 'C3') is cheking
# Arc ('C1', 'C4') is cheking
# Arc ('C1', 'C5') is cheking
# Arc ('C1', 'C6') is cheking
# The val 5 was deleted from C1 domain
# Arc ('C1', 'C7') is cheking
# Arc ('C1', 'C8') is cheking
# The val 7 was deleted from C1 domain
# Arc ('C1', 'C9') is cheking
# Arc ('C1', 'D1') is cheking
# Arc ('C1', 'E1') is cheking
# Arc ('C1', 'F1') is cheking
# Arc ('C1', 'G1') is cheking
# Arc ('C1', 'H1') is cheking
# Arc ('C1', 'I1') is cheking
# Arc ('C2', 'A1') is cheking
# Arc ('C2', 'A2') is cheking
# Arc ('C2', 'A3') is cheking
# Arc ('C2', 'B1') is cheking
# Arc ('C2', 'B2') is cheking
# Arc ('C2', 'B3') is cheking
# Arc ('C2', 'C1') is cheking
# Arc ('C2', 'C3') is cheking
# Arc ('C2', 'C4') is cheking
# Arc ('C2', 'C5') is cheking
# Arc ('C2', 'C6') is cheking
# Arc ('C2', 'C7') is cheking
# Arc ('C2', 'C8') is cheking
# Arc ('C2', 'C9') is cheking
# Arc ('C2', 'D2') is cheking
# Arc ('C2', 'E2') is cheking
# Arc ('C2', 'F2') is cheking
# Arc ('C2', 'G2') is cheking
# Arc ('C2', 'H2') is cheking
# Arc ('C2', 'I2') is cheking
# Arc ('C3', 'A1') is cheking
# Arc ('C3', 'A2') is cheking
# The val 1 was deleted from C3 domain
# Arc ('C3', 'A3') is cheking
# Arc ('C3', 'B1') is cheking
# The val 3 was deleted from C3 domain
# Arc ('C3', 'B2') is cheking
# Arc ('C3', 'B3') is cheking
# The val 9 was deleted from C3 domain
# Arc ('C3', 'B5') is cheking
# Arc ('C3', 'C1') is cheking
# Arc ('C3', 'C2') is cheking
# The val 8 was deleted from C3 domain
# Arc ('C3', 'C4') is cheking
# Arc ('C3', 'C5') is cheking
# Arc ('C3', 'C6') is cheking
# The val 5 was deleted from C3 domain
# Arc ('C3', 'C7') is cheking
# Arc ('C3', 'C8') is cheking
# The val 7 was deleted from C3 domain
# Arc ('C3', 'C9') is cheking
# Arc ('C3', 'D3') is cheking
# The val 2 was deleted from C3 domain
# Arc ('C3', 'E2') is cheking
# Arc ('C3', 'E3') is cheking
# Arc ('C3', 'E5') is cheking
# Arc ('C3', 'E8') is cheking
# Arc ('C3', 'F3') is cheking
# Arc ('C3', 'G3') is cheking
# Arc ('C3', 'G7') is cheking
# Arc ('C3', 'H3') is cheking
# The val 4 was deleted from C3 domain
# Arc ('C3', 'H5') is cheking
# Arc ('C3', 'I3') is cheking
# Arc ('C4', 'A4') is cheking
# Arc ('C4', 'A5') is cheking
# Arc ('C4', 'A6') is cheking
# Arc ('C4', 'B4') is cheking
# Arc ('C4', 'B5') is cheking
# Arc ('C4', 'B6') is cheking
# Arc ('C4', 'C1') is cheking
# Arc ('C4', 'C2') is cheking
# Arc ('C4', 'C3') is cheking
# Arc ('C4', 'C5') is cheking
# Arc ('C4', 'C6') is cheking
# Arc ('C4', 'C7') is cheking
# Arc ('C4', 'C8') is cheking
# Arc ('C4', 'C9') is cheking
# Arc ('C4', 'D4') is cheking
# Arc ('C4', 'E4') is cheking
# Arc ('C4', 'F4') is cheking
# Arc ('C4', 'G4') is cheking
# Arc ('C4', 'H4') is cheking
# Arc ('C4', 'I4') is cheking
# Arc ('C5', 'A4') is cheking
# Arc ('C5', 'A5') is cheking
# Arc ('C5', 'A6') is cheking
# Arc ('C5', 'B4') is cheking
# Arc ('C5', 'B5') is cheking
# Arc ('C5', 'B6') is cheking
# Arc ('C5', 'C1') is cheking
# Arc ('C5', 'C2') is cheking
# The val 8 was deleted from C5 domain
# Arc ('C5', 'C3') is cheking
# The val 6 was deleted from C5 domain
# Arc ('C5', 'C4') is cheking
# The val 3 was deleted from C5 domain
# Arc ('C5', 'C6') is cheking
# The val 5 was deleted from C5 domain
# Arc ('C5', 'C7') is cheking
# Arc ('C5', 'C8') is cheking
# The val 7 was deleted from C5 domain
# Arc ('C5', 'C9') is cheking
# Arc ('C5', 'D5') is cheking
# Arc ('C5', 'E5') is cheking
# Arc ('C5', 'F5') is cheking
# The val 9 was deleted from C5 domain
# Arc ('C5', 'G5') is cheking
# Arc ('C5', 'H5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('C6', 'A4') is cheking
# Arc ('C6', 'A5') is cheking
# Arc ('C6', 'A6') is cheking
# Arc ('C6', 'B4') is cheking
# Arc ('C6', 'B5') is cheking
# Arc ('C6', 'B6') is cheking
# Arc ('C6', 'C1') is cheking
# Arc ('C6', 'C2') is cheking
# Arc ('C6', 'C3') is cheking
# Arc ('C6', 'C4') is cheking
# Arc ('C6', 'C5') is cheking
# Arc ('C6', 'C7') is cheking
# Arc ('C6', 'C8') is cheking
# Arc ('C6', 'C9') is cheking
# Arc ('C6', 'D6') is cheking
# Arc ('C6', 'E6') is cheking
# Arc ('C6', 'F6') is cheking
# Arc ('C6', 'G6') is cheking
# Arc ('C6', 'H6') is cheking
# Arc ('C6', 'I6') is cheking
# Arc ('C7', 'A7') is cheking
# Arc ('C7', 'A8') is cheking
# The val 6 was deleted from C7 domain
# Arc ('C7', 'A9') is cheking
# Arc ('C7', 'B5') is cheking
# Arc ('C7', 'B7') is cheking
# The val 1 was deleted from C7 domain
# Arc ('C7', 'B8') is cheking
# Arc ('C7', 'B9') is cheking
# The val 5 was deleted from C7 domain
# Arc ('C7', 'C1') is cheking
# Arc ('C7', 'C2') is cheking
# The val 8 was deleted from C7 domain
# Arc ('C7', 'C3') is cheking
# Arc ('C7', 'C4') is cheking
# The val 3 was deleted from C7 domain
# Arc ('C7', 'C5') is cheking
# Arc ('C7', 'C6') is cheking
# Arc ('C7', 'C8') is cheking
# The val 7 was deleted from C7 domain
# Arc ('C7', 'C9') is cheking
# Arc ('C7', 'D7') is cheking
# Arc ('C7', 'E2') is cheking
# Arc ('C7', 'E5') is cheking
# Arc ('C7', 'E7') is cheking
# Arc ('C7', 'E8') is cheking
# Arc ('C7', 'F7') is cheking
# The val 2 was deleted from C7 domain
# Arc ('C7', 'G3') is cheking
# Arc ('C7', 'G7') is cheking
# Arc ('C7', 'H5') is cheking
# Arc ('C7', 'H7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('C8', 'A7') is cheking
# Arc ('C8', 'A8') is cheking
# Arc ('C8', 'A9') is cheking
# Arc ('C8', 'B7') is cheking
# Arc ('C8', 'B8') is cheking
# Arc ('C8', 'B9') is cheking
# Arc ('C8', 'C1') is cheking
# Arc ('C8', 'C2') is cheking
# Arc ('C8', 'C3') is cheking
# Arc ('C8', 'C4') is cheking
# Arc ('C8', 'C5') is cheking
# Arc ('C8', 'C6') is cheking
# Arc ('C8', 'C7') is cheking
# Arc ('C8', 'C9') is cheking
# Arc ('C8', 'D8') is cheking
# Arc ('C8', 'E8') is cheking
# Arc ('C8', 'F8') is cheking
# Arc ('C8', 'G8') is cheking
# Arc ('C8', 'H8') is cheking
# Arc ('C8', 'I8') is cheking
# Arc ('C9', 'A7') is cheking
# Arc ('C9', 'A8') is cheking
# The val 6 was deleted from C9 domain
# Arc ('C9', 'A9') is cheking
# Arc ('C9', 'B7') is cheking
# The val 1 was deleted from C9 domain
# Arc ('C9', 'B8') is cheking
# Arc ('C9', 'B9') is cheking
# The val 5 was deleted from C9 domain
# Arc ('C9', 'C1') is cheking
# Arc ('C9', 'C2') is cheking
# The val 8 was deleted from C9 domain
# Arc ('C9', 'C3') is cheking
# Arc ('C9', 'C4') is cheking
# The val 3 was deleted from C9 domain
# Arc ('C9', 'C5') is cheking
# Arc ('C9', 'C6') is cheking
# Arc ('C9', 'C7') is cheking
# Arc ('C9', 'C8') is cheking
# The val 7 was deleted from C9 domain
# Arc ('C9', 'D9') is cheking
# Arc ('C9', 'E9') is cheking
# Arc ('C9', 'F9') is cheking
# Arc ('C9', 'G9') is cheking
# Arc ('C9', 'H9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D1', 'A1') is cheking
# Arc ('D1', 'B1') is cheking
# The val 3 was deleted from D1 domain
# Arc ('D1', 'C1') is cheking
# Arc ('D1', 'D2') is cheking
# Arc ('D1', 'D3') is cheking
# The val 2 was deleted from D1 domain
# Arc ('D1', 'D4') is cheking
# Arc ('D1', 'D5') is cheking
# The val 7 was deleted from D1 domain
# Arc ('D1', 'D6') is cheking
# Arc ('D1', 'D7') is cheking
# The val 8 was deleted from D1 domain
# Arc ('D1', 'D8') is cheking
# Arc ('D1', 'D9') is cheking
# Arc ('D1', 'E1') is cheking
# Arc ('D1', 'E2') is cheking
# Arc ('D1', 'E3') is cheking
# Arc ('D1', 'F1') is cheking
# Arc ('D1', 'F2') is cheking
# Arc ('D1', 'F3') is cheking
# Arc ('D1', 'G1') is cheking
# Arc ('D1', 'H1') is cheking
# The val 9 was deleted from D1 domain
# Arc ('D1', 'I1') is cheking
# Arc ('D2', 'A2') is cheking
# The val 1 was deleted from D2 domain
# Arc ('D2', 'B2') is cheking
# Arc ('D2', 'C2') is cheking
# The val 8 was deleted from D2 domain
# Arc ('D2', 'D1') is cheking
# Arc ('D2', 'D3') is cheking
# The val 2 was deleted from D2 domain
# Arc ('D2', 'D4') is cheking
# Arc ('D2', 'D5') is cheking
# The val 7 was deleted from D2 domain
# Arc ('D2', 'D6') is cheking
# Arc ('D2', 'D7') is cheking
# Arc ('D2', 'D8') is cheking
# Arc ('D2', 'D9') is cheking
# Arc ('D2', 'E1') is cheking
# Arc ('D2', 'E2') is cheking
# Arc ('D2', 'E3') is cheking
# Arc ('D2', 'F1') is cheking
# Arc ('D2', 'F2') is cheking
# Arc ('D2', 'F3') is cheking
# Arc ('D2', 'G2') is cheking
# Arc ('D2', 'H2') is cheking
# Arc ('D2', 'I2') is cheking
# The val 3 was deleted from D2 domain
# Arc ('D3', 'A3') is cheking
# Arc ('D3', 'B3') is cheking
# Arc ('D3', 'C3') is cheking
# Arc ('D3', 'D1') is cheking
# Arc ('D3', 'D2') is cheking
# Arc ('D3', 'D4') is cheking
# Arc ('D3', 'D5') is cheking
# Arc ('D3', 'D6') is cheking
# Arc ('D3', 'D7') is cheking
# Arc ('D3', 'D8') is cheking
# Arc ('D3', 'D9') is cheking
# Arc ('D3', 'E1') is cheking
# Arc ('D3', 'E2') is cheking
# Arc ('D3', 'E3') is cheking
# Arc ('D3', 'F1') is cheking
# Arc ('D3', 'F2') is cheking
# Arc ('D3', 'F3') is cheking
# Arc ('D3', 'G3') is cheking
# Arc ('D3', 'H3') is cheking
# Arc ('D3', 'I3') is cheking
# Arc ('D4', 'A4') is cheking
# Arc ('D4', 'B4') is cheking
# Arc ('D4', 'C4') is cheking
# The val 3 was deleted from D4 domain
# Arc ('D4', 'D1') is cheking
# Arc ('D4', 'D2') is cheking
# Arc ('D4', 'D3') is cheking
# The val 2 was deleted from D4 domain
# Arc ('D4', 'D5') is cheking
# The val 7 was deleted from D4 domain
# Arc ('D4', 'D6') is cheking
# Arc ('D4', 'D7') is cheking
# The val 8 was deleted from D4 domain
# Arc ('D4', 'D8') is cheking
# Arc ('D4', 'D9') is cheking
# Arc ('D4', 'E4') is cheking
# The val 6 was deleted from D4 domain
# Arc ('D4', 'E5') is cheking
# Arc ('D4', 'E6') is cheking
# Arc ('D4', 'F4') is cheking
# Arc ('D4', 'F5') is cheking
# The val 9 was deleted from D4 domain
# Arc ('D4', 'F6') is cheking
# Arc ('D4', 'G4') is cheking
# The val 4 was deleted from D4 domain
# Arc ('D4', 'H4') is cheking
# Arc ('D4', 'I4') is cheking
# Arc ('D5', 'A5') is cheking
# Arc ('D5', 'B5') is cheking
# Arc ('D5', 'C5') is cheking
# Arc ('D5', 'D1') is cheking
# Arc ('D5', 'D2') is cheking
# Arc ('D5', 'D3') is cheking
# Arc ('D5', 'D4') is cheking
# Arc ('D5', 'D6') is cheking
# Arc ('D5', 'D7') is cheking
# Arc ('D5', 'D8') is cheking
# Arc ('D5', 'D9') is cheking
# Arc ('D5', 'E4') is cheking
# Arc ('D5', 'E5') is cheking
# Arc ('D5', 'E6') is cheking
# Arc ('D5', 'F4') is cheking
# Arc ('D5', 'F5') is cheking
# Arc ('D5', 'F6') is cheking
# Arc ('D5', 'G5') is cheking
# Arc ('D5', 'H5') is cheking
# Arc ('D5', 'I5') is cheking
# Arc ('D6', 'A6') is cheking
# Arc ('D6', 'B6') is cheking
# Arc ('D6', 'C6') is cheking
# The val 5 was deleted from D6 domain
# Arc ('D6', 'D1') is cheking
# Arc ('D6', 'D2') is cheking
# Arc ('D6', 'D3') is cheking
# The val 2 was deleted from D6 domain
# Arc ('D6', 'D4') is cheking
# Arc ('D6', 'D5') is cheking
# The val 7 was deleted from D6 domain
# Arc ('D6', 'D7') is cheking
# The val 8 was deleted from D6 domain
# Arc ('D6', 'D8') is cheking
# Arc ('D6', 'D9') is cheking
# Arc ('D6', 'E4') is cheking
# The val 6 was deleted from D6 domain
# Arc ('D6', 'E5') is cheking
# Arc ('D6', 'E6') is cheking
# Arc ('D6', 'F4') is cheking
# Arc ('D6', 'F5') is cheking
# The val 9 was deleted from D6 domain
# Arc ('D6', 'F6') is cheking
# Arc ('D6', 'G6') is cheking
# The val 1 was deleted from D6 domain
# Arc ('D6', 'H6') is cheking
# Arc ('D6', 'I6') is cheking
# Arc ('D7', 'A7') is cheking
# Arc ('D7', 'B7') is cheking
# Arc ('D7', 'C7') is cheking
# Arc ('D7', 'D1') is cheking
# Arc ('D7', 'D2') is cheking
# Arc ('D7', 'D3') is cheking
# Arc ('D7', 'D4') is cheking
# Arc ('D7', 'D5') is cheking
# Arc ('D7', 'D6') is cheking
# Arc ('D7', 'D8') is cheking
# Arc ('D7', 'D9') is cheking
# Arc ('D7', 'E7') is cheking
# Arc ('D7', 'E8') is cheking
# Arc ('D7', 'E9') is cheking
# Arc ('D7', 'F7') is cheking
# Arc ('D7', 'F8') is cheking
# Arc ('D7', 'F9') is cheking
# Arc ('D7', 'G7') is cheking
# Arc ('D7', 'H7') is cheking
# Arc ('D7', 'I7') is cheking
# Arc ('D8', 'A8') is cheking
# The val 6 was deleted from D8 domain
# Arc ('D8', 'B8') is cheking
# Arc ('D8', 'C8') is cheking
# The val 7 was deleted from D8 domain
# Arc ('D8', 'D1') is cheking
# Arc ('D8', 'D2') is cheking
# Arc ('D8', 'D3') is cheking
# The val 2 was deleted from D8 domain
# Arc ('D8', 'D4') is cheking
# Arc ('D8', 'D5') is cheking
# Arc ('D8', 'D6') is cheking
# Arc ('D8', 'D7') is cheking
# The val 8 was deleted from D8 domain
# Arc ('D8', 'D9') is cheking
# Arc ('D8', 'E7') is cheking
# Arc ('D8', 'E8') is cheking
# Arc ('D8', 'E9') is cheking
# Arc ('D8', 'F7') is cheking
# Arc ('D8', 'F8') is cheking
# Arc ('D8', 'F9') is cheking
# Arc ('D8', 'G8') is cheking
# The val 9 was deleted from D8 domain
# Arc ('D8', 'H8') is cheking
# Arc ('D8', 'I8') is cheking
# Arc ('D9', 'A9') is cheking
# Arc ('D9', 'B9') is cheking
# The val 5 was deleted from D9 domain
# Arc ('D9', 'C9') is cheking
# Arc ('D9', 'D1') is cheking
# Arc ('D9', 'D2') is cheking
# Arc ('D9', 'D3') is cheking
# The val 2 was deleted from D9 domain
# Arc ('D9', 'D4') is cheking
# Arc ('D9', 'D5') is cheking
# The val 7 was deleted from D9 domain
# Arc ('D9', 'D6') is cheking
# Arc ('D9', 'D7') is cheking
# The val 8 was deleted from D9 domain
# Arc ('D9', 'D8') is cheking
# Arc ('D9', 'E7') is cheking
# Arc ('D9', 'E8') is cheking
# Arc ('D9', 'E9') is cheking
# Arc ('D9', 'F7') is cheking
# Arc ('D9', 'F8') is cheking
# Arc ('D9', 'F9') is cheking
# Arc ('D9', 'G9') is cheking
# Arc ('D9', 'H9') is cheking
# The val 1 was deleted from D9 domain
# Arc ('D9', 'I9') is cheking
# Arc ('E1', 'A1') is cheking
# Arc ('E1', 'B1') is cheking
# The val 3 was deleted from E1 domain
# Arc ('E1', 'C1') is cheking
# Arc ('E1', 'D1') is cheking
# Arc ('E1', 'D2') is cheking
# Arc ('E1', 'D3') is cheking
# The val 2 was deleted from E1 domain
# Arc ('E1', 'E2') is cheking
# Arc ('E1', 'E3') is cheking
# Arc ('E1', 'E4') is cheking
# The val 6 was deleted from E1 domain
# Arc ('E1', 'E5') is cheking
# Arc ('E1', 'E6') is cheking
# The val 8 was deleted from E1 domain
# Arc ('E1', 'E7') is cheking
# Arc ('E1', 'E8') is cheking
# Arc ('E1', 'E9') is cheking
# ...
# Arc ('G5', 'I4') is cheking
# Arc ('G6', 'I4') is cheking
# Arc ('H4', 'I4') is cheking
# Arc ('H5', 'I4') is cheking
# Arc ('H6', 'I4') is cheking
# Arc ('I1', 'I4') is cheking
# Arc ('I2', 'I4') is cheking
# Arc ('I3', 'I4') is cheking
# Arc ('I5', 'I4') is cheking
# Arc ('I6', 'I4') is cheking
# Arc ('I7', 'I4') is cheking
# Arc ('I8', 'I4') is cheking
# Arc ('I9', 'I4') is cheking
# Arc ('A4', 'I4') is cheking
# Arc ('B4', 'I4') is cheking
# Arc ('C4', 'I4') is cheking
# Arc ('D4', 'I4') is cheking
# Arc ('E4', 'I4') is cheking
# Arc ('F4', 'I4') is cheking
# Arc ('G5', 'I4') is cheking
# Arc ('G6', 'I4') is cheking
# Arc ('H4', 'I4') is cheking
# Arc ('H5', 'I4') is cheking
# Arc ('H6', 'I4') is cheking
# Arc ('I1', 'I4') is cheking
# Arc ('I2', 'I4') is cheking
# Arc ('I3', 'I4') is cheking
# Arc ('I5', 'I4') is cheking
# Arc ('I6', 'I4') is cheking
# Arc ('I7', 'I4') is cheking
# Arc ('I8', 'I4') is cheking
# Arc ('I9', 'I4') is cheking
# Arc ('A4', 'I4') is cheking
# Arc ('B4', 'I4') is cheking
# Arc ('C4', 'I4') is cheking
# Arc ('D4', 'I4') is cheking
# Arc ('E4', 'I4') is cheking
# Arc ('F4', 'I4') is cheking
# Arc ('G4', 'I4') is cheking
# Arc ('G5', 'I4') is cheking
# Arc ('H4', 'I4') is cheking
# Arc ('H5', 'I4') is cheking
# Arc ('H6', 'I4') is cheking
# Arc ('I1', 'I4') is cheking
# Arc ('I2', 'I4') is cheking
# Arc ('I3', 'I4') is cheking
# Arc ('I5', 'I4') is cheking
# Arc ('I6', 'I4') is cheking
# Arc ('I7', 'I4') is cheking
# Arc ('I8', 'I4') is cheking
# Arc ('I9', 'I4') is cheking
# Arc ('A4', 'I4') is cheking
# Arc ('B4', 'I4') is cheking
# Arc ('C4', 'I4') is cheking
# Arc ('D4', 'I4') is cheking
# Arc ('E4', 'I4') is cheking
# Arc ('F4', 'I4') is cheking
# Arc ('G4', 'I4') is cheking
# Arc ('G5', 'I4') is cheking
# Arc ('G6', 'I4') is cheking
# Arc ('H4', 'I4') is cheking
# Arc ('H5', 'I4') is cheking
# Arc ('H6', 'I4') is cheking
# Arc ('I1', 'I4') is cheking
# Arc ('I2', 'I4') is cheking
# Arc ('I3', 'I4') is cheking
# Arc ('I5', 'I4') is cheking
# Arc ('I6', 'I4') is cheking
# Arc ('I7', 'I4') is cheking
# Arc ('I9', 'I4') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('E5', 'I5') is cheking
# Arc ('F5', 'I5') is cheking
# Arc ('G4', 'I5') is cheking
# Arc ('G5', 'I5') is cheking
# Arc ('G6', 'I5') is cheking
# Arc ('H4', 'I5') is cheking
# Arc ('H5', 'I5') is cheking
# Arc ('H6', 'I5') is cheking
# Arc ('I1', 'I5') is cheking
# Arc ('I2', 'I5') is cheking
# Arc ('I3', 'I5') is cheking
# Arc ('I4', 'I5') is cheking
# Arc ('I6', 'I5') is cheking
# Arc ('I7', 'I5') is cheking
# Arc ('I8', 'I5') is cheking
# Arc ('I9', 'I5') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('D5', 'I5') is cheking
# Arc ('E5', 'I5') is cheking
# Arc ('G4', 'I5') is cheking
# Arc ('G5', 'I5') is cheking
# Arc ('G6', 'I5') is cheking
# Arc ('H4', 'I5') is cheking
# Arc ('H5', 'I5') is cheking
# Arc ('H6', 'I5') is cheking
# Arc ('I1', 'I5') is cheking
# Arc ('I2', 'I5') is cheking
# Arc ('I3', 'I5') is cheking
# Arc ('I4', 'I5') is cheking
# Arc ('I6', 'I5') is cheking
# Arc ('I7', 'I5') is cheking
# Arc ('I8', 'I5') is cheking
# Arc ('I9', 'I5') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('D5', 'I5') is cheking
# Arc ('E5', 'I5') is cheking
# Arc ('F5', 'I5') is cheking
# Arc ('G5', 'I5') is cheking
# Arc ('G6', 'I5') is cheking
# Arc ('H4', 'I5') is cheking
# Arc ('H5', 'I5') is cheking
# Arc ('H6', 'I5') is cheking
# Arc ('I1', 'I5') is cheking
# Arc ('I2', 'I5') is cheking
# Arc ('I3', 'I5') is cheking
# Arc ('I4', 'I5') is cheking
# Arc ('I6', 'I5') is cheking
# Arc ('I7', 'I5') is cheking
# Arc ('I8', 'I5') is cheking
# Arc ('I9', 'I5') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('D5', 'I5') is cheking
# Arc ('E5', 'I5') is cheking
# Arc ('F5', 'I5') is cheking
# Arc ('G4', 'I5') is cheking
# Arc ('G5', 'I5') is cheking
# Arc ('H4', 'I5') is cheking
# Arc ('H5', 'I5') is cheking
# Arc ('H6', 'I5') is cheking
# Arc ('I1', 'I5') is cheking
# Arc ('I2', 'I5') is cheking
# Arc ('I3', 'I5') is cheking
# Arc ('I4', 'I5') is cheking
# Arc ('I6', 'I5') is cheking
# Arc ('I7', 'I5') is cheking
# Arc ('I8', 'I5') is cheking
# Arc ('I9', 'I5') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('D5', 'I5') is cheking
# Arc ('E5', 'I5') is cheking
# Arc ('F5', 'I5') is cheking
# Arc ('G4', 'I5') is cheking
# Arc ('G5', 'I5') is cheking
# Arc ('G6', 'I5') is cheking
# Arc ('H4', 'I5') is cheking
# Arc ('H5', 'I5') is cheking
# Arc ('H6', 'I5') is cheking
# Arc ('I1', 'I5') is cheking
# Arc ('I3', 'I5') is cheking
# Arc ('I4', 'I5') is cheking
# Arc ('I6', 'I5') is cheking
# Arc ('I7', 'I5') is cheking
# Arc ('I8', 'I5') is cheking
# Arc ('I9', 'I5') is cheking
# Arc ('A5', 'I5') is cheking
# Arc ('B5', 'I5') is cheking
# Arc ('C5', 'I5') is cheking
# Arc ('D5', 'I5') is cheking
# Arc ('E5', 'I5') is cheking
# Arc ('F5', 'I5') is cheking
# Arc ('G4', 'I5') is cheking
# Arc ('G5', 'I5') is cheking
# Arc ('G6', 'I5') is cheking
# Arc ('H4', 'I5') is cheking
# Arc ('H5', 'I5') is cheking
# Arc ('H6', 'I5') is cheking
# Arc ('I1', 'I5') is cheking
# Arc ('I2', 'I5') is cheking
# Arc ('I3', 'I5') is cheking
# Arc ('I4', 'I5') is cheking
# Arc ('I6', 'I5') is cheking
# Arc ('I7', 'I5') is cheking
# Arc ('I9', 'I5') is cheking
# Arc ('A6', 'I6') is cheking
# Arc ('B6', 'I6') is cheking
# Arc ('D6', 'I6') is cheking
# Arc ('E6', 'I6') is cheking
# Arc ('F6', 'I6') is cheking
# Arc ('G4', 'I6') is cheking
# Arc ('G5', 'I6') is cheking
# Arc ('G6', 'I6') is cheking
# Arc ('H4', 'I6') is cheking
# Arc ('H5', 'I6') is cheking
# Arc ('H6', 'I6') is cheking
# Arc ('I1', 'I6') is cheking
# Arc ('I2', 'I6') is cheking
# Arc ('I3', 'I6') is cheking
# Arc ('I4', 'I6') is cheking
# Arc ('I5', 'I6') is cheking
# Arc ('I7', 'I6') is cheking
# Arc ('I8', 'I6') is cheking
# Arc ('I9', 'I6') is cheking
# Arc ('A6', 'I6') is cheking
# Arc ('B6', 'I6') is cheking
# Arc ('C6', 'I6') is cheking
# Arc ('D6', 'I6') is cheking
# Arc ('F6', 'I6') is cheking
# Arc ('G4', 'I6') is cheking
# Arc ('G5', 'I6') is cheking
# Arc ('G6', 'I6') is cheking
# Arc ('H4', 'I6') is cheking
# Arc ('H5', 'I6') is cheking
# Arc ('H6', 'I6') is cheking
# Arc ('I1', 'I6') is cheking
# Arc ('I2', 'I6') is cheking
# Arc ('I3', 'I6') is cheking
# Arc ('I4', 'I6') is cheking
# Arc ('I5', 'I6') is cheking
# Arc ('I7', 'I6') is cheking
# Arc ('I8', 'I6') is cheking
# Arc ('I9', 'I6') is cheking
# Arc ('A6', 'I6') is cheking
# Arc ('B6', 'I6') is cheking
# Arc ('C6', 'I6') is cheking
# Arc ('D6', 'I6') is cheking
# Arc ('E6', 'I6') is cheking
# Arc ('F6', 'I6') is cheking
# Arc ('G5', 'I6') is cheking
# Arc ('G6', 'I6') is cheking
# Arc ('H4', 'I6') is cheking
# Arc ('H5', 'I6') is cheking
# Arc ('H6', 'I6') is cheking
# Arc ('I1', 'I6') is cheking
# Arc ('I2', 'I6') is cheking
# Arc ('I3', 'I6') is cheking
# Arc ('I4', 'I6') is cheking
# Arc ('I5', 'I6') is cheking
# Arc ('I7', 'I6') is cheking
# Arc ('I8', 'I6') is cheking
# Arc ('I9', 'I6') is cheking
# Arc ('A6', 'I6') is cheking
# Arc ('B6', 'I6') is cheking
# Arc ('C6', 'I6') is cheking
# Arc ('D6', 'I6') is cheking
# Arc ('E6', 'I6') is cheking
# Arc ('F6', 'I6') is cheking
# Arc ('G4', 'I6') is cheking
# Arc ('G5', 'I6') is cheking
# Arc ('H4', 'I6') is cheking
# Arc ('H5', 'I6') is cheking
# Arc ('H6', 'I6') is cheking
# Arc ('I1', 'I6') is cheking
# Arc ('I2', 'I6') is cheking
# Arc ('I3', 'I6') is cheking
# Arc ('I4', 'I6') is cheking
# Arc ('I5', 'I6') is cheking
# Arc ('I7', 'I6') is cheking
# Arc ('I8', 'I6') is cheking
# Arc ('I9', 'I6') is cheking
# Arc ('A6', 'I6') is cheking
# Arc ('B6', 'I6') is cheking
# Arc ('C6', 'I6') is cheking
# Arc ('D6', 'I6') is cheking
# Arc ('E6', 'I6') is cheking
# Arc ('F6', 'I6') is cheking
# Arc ('G4', 'I6') is cheking
# Arc ('G5', 'I6') is cheking
# Arc ('G6', 'I6') is cheking
# Arc ('H4', 'I6') is cheking
# Arc ('H5', 'I6') is cheking
# Arc ('H6', 'I6') is cheking
# Arc ('I1', 'I6') is cheking
# Arc ('I3', 'I6') is cheking
# Arc ('I4', 'I6') is cheking
# Arc ('I5', 'I6') is cheking
# Arc ('I7', 'I6') is cheking
# Arc ('I8', 'I6') is cheking
# Arc ('I9', 'I6') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('D7', 'I7') is cheking
# Arc ('E7', 'I7') is cheking
# Arc ('F7', 'I7') is cheking
# Arc ('G7', 'I7') is cheking
# Arc ('G8', 'I7') is cheking
# Arc ('G9', 'I7') is cheking
# Arc ('H7', 'I7') is cheking
# Arc ('H8', 'I7') is cheking
# Arc ('H9', 'I7') is cheking
# Arc ('I1', 'I7') is cheking
# Arc ('I2', 'I7') is cheking
# Arc ('I3', 'I7') is cheking
# Arc ('I4', 'I7') is cheking
# Arc ('I5', 'I7') is cheking
# Arc ('I6', 'I7') is cheking
# Arc ('I8', 'I7') is cheking
# Arc ('I9', 'I7') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('B7', 'I7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('E7', 'I7') is cheking
# Arc ('F7', 'I7') is cheking
# Arc ('G7', 'I7') is cheking
# Arc ('G8', 'I7') is cheking
# Arc ('G9', 'I7') is cheking
# Arc ('H7', 'I7') is cheking
# Arc ('H8', 'I7') is cheking
# Arc ('H9', 'I7') is cheking
# Arc ('I1', 'I7') is cheking
# Arc ('I2', 'I7') is cheking
# Arc ('I3', 'I7') is cheking
# Arc ('I4', 'I7') is cheking
# Arc ('I5', 'I7') is cheking
# Arc ('I6', 'I7') is cheking
# Arc ('I8', 'I7') is cheking
# Arc ('I9', 'I7') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('B7', 'I7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('D7', 'I7') is cheking
# Arc ('E7', 'I7') is cheking
# Arc ('G7', 'I7') is cheking
# Arc ('G8', 'I7') is cheking
# Arc ('G9', 'I7') is cheking
# Arc ('H7', 'I7') is cheking
# Arc ('H8', 'I7') is cheking
# Arc ('H9', 'I7') is cheking
# Arc ('I1', 'I7') is cheking
# Arc ('I2', 'I7') is cheking
# Arc ('I3', 'I7') is cheking
# Arc ('I4', 'I7') is cheking
# Arc ('I5', 'I7') is cheking
# Arc ('I6', 'I7') is cheking
# Arc ('I8', 'I7') is cheking
# Arc ('I9', 'I7') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('B7', 'I7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('D7', 'I7') is cheking
# Arc ('E7', 'I7') is cheking
# Arc ('F7', 'I7') is cheking
# Arc ('G7', 'I7') is cheking
# Arc ('G9', 'I7') is cheking
# Arc ('H7', 'I7') is cheking
# Arc ('H8', 'I7') is cheking
# Arc ('H9', 'I7') is cheking
# Arc ('I1', 'I7') is cheking
# Arc ('I2', 'I7') is cheking
# Arc ('I3', 'I7') is cheking
# Arc ('I4', 'I7') is cheking
# Arc ('I5', 'I7') is cheking
# Arc ('I6', 'I7') is cheking
# Arc ('I8', 'I7') is cheking
# Arc ('I9', 'I7') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('B7', 'I7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('D7', 'I7') is cheking
# Arc ('E7', 'I7') is cheking
# Arc ('F7', 'I7') is cheking
# Arc ('G7', 'I7') is cheking
# Arc ('G8', 'I7') is cheking
# Arc ('G9', 'I7') is cheking
# Arc ('H8', 'I7') is cheking
# Arc ('H9', 'I7') is cheking
# Arc ('I1', 'I7') is cheking
# Arc ('I2', 'I7') is cheking
# Arc ('I3', 'I7') is cheking
# Arc ('I4', 'I7') is cheking
# Arc ('I5', 'I7') is cheking
# Arc ('I6', 'I7') is cheking
# Arc ('I8', 'I7') is cheking
# Arc ('I9', 'I7') is cheking
# Arc ('A7', 'I7') is cheking
# Arc ('B7', 'I7') is cheking
# Arc ('C7', 'I7') is cheking
# Arc ('D7', 'I7') is cheking
# Arc ('E7', 'I7') is cheking
# Arc ('F7', 'I7') is cheking
# Arc ('G7', 'I7') is cheking
# Arc ('G8', 'I7') is cheking
# Arc ('G9', 'I7') is cheking
# Arc ('H7', 'I7') is cheking
# Arc ('H8', 'I7') is cheking
# Arc ('H9', 'I7') is cheking
# Arc ('I1', 'I7') is cheking
# Arc ('I3', 'I7') is cheking
# Arc ('I4', 'I7') is cheking
# Arc ('I5', 'I7') is cheking
# Arc ('I6', 'I7') is cheking
# Arc ('I8', 'I7') is cheking
# Arc ('I9', 'I7') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D9', 'I9') is cheking
# Arc ('E9', 'I9') is cheking
# Arc ('F9', 'I9') is cheking
# Arc ('G7', 'I9') is cheking
# Arc ('G8', 'I9') is cheking
# Arc ('G9', 'I9') is cheking
# Arc ('H7', 'I9') is cheking
# Arc ('H8', 'I9') is cheking
# Arc ('H9', 'I9') is cheking
# Arc ('I1', 'I9') is cheking
# Arc ('I2', 'I9') is cheking
# Arc ('I3', 'I9') is cheking
# Arc ('I4', 'I9') is cheking
# Arc ('I5', 'I9') is cheking
# Arc ('I6', 'I9') is cheking
# Arc ('I7', 'I9') is cheking
# Arc ('I8', 'I9') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('B9', 'I9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D9', 'I9') is cheking
# Arc ('E9', 'I9') is cheking
# Arc ('F9', 'I9') is cheking
# Arc ('G7', 'I9') is cheking
# Arc ('G9', 'I9') is cheking
# Arc ('H7', 'I9') is cheking
# Arc ('H8', 'I9') is cheking
# Arc ('H9', 'I9') is cheking
# Arc ('I1', 'I9') is cheking
# Arc ('I2', 'I9') is cheking
# Arc ('I3', 'I9') is cheking
# Arc ('I4', 'I9') is cheking
# Arc ('I5', 'I9') is cheking
# Arc ('I6', 'I9') is cheking
# Arc ('I7', 'I9') is cheking
# Arc ('I8', 'I9') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('B9', 'I9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D9', 'I9') is cheking
# Arc ('E9', 'I9') is cheking
# Arc ('F9', 'I9') is cheking
# Arc ('G7', 'I9') is cheking
# Arc ('G8', 'I9') is cheking
# Arc ('G9', 'I9') is cheking
# Arc ('H8', 'I9') is cheking
# Arc ('H9', 'I9') is cheking
# Arc ('I1', 'I9') is cheking
# Arc ('I2', 'I9') is cheking
# Arc ('I3', 'I9') is cheking
# Arc ('I4', 'I9') is cheking
# Arc ('I5', 'I9') is cheking
# Arc ('I6', 'I9') is cheking
# Arc ('I7', 'I9') is cheking
# Arc ('I8', 'I9') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('B9', 'I9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D9', 'I9') is cheking
# Arc ('E9', 'I9') is cheking
# Arc ('F9', 'I9') is cheking
# Arc ('G7', 'I9') is cheking
# Arc ('G8', 'I9') is cheking
# Arc ('G9', 'I9') is cheking
# Arc ('H7', 'I9') is cheking
# Arc ('H8', 'I9') is cheking
# Arc ('I1', 'I9') is cheking
# Arc ('I2', 'I9') is cheking
# Arc ('I3', 'I9') is cheking
# Arc ('I4', 'I9') is cheking
# Arc ('I5', 'I9') is cheking
# Arc ('I6', 'I9') is cheking
# Arc ('I7', 'I9') is cheking
# Arc ('I8', 'I9') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('B9', 'I9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D9', 'I9') is cheking
# Arc ('E9', 'I9') is cheking
# Arc ('F9', 'I9') is cheking
# Arc ('G7', 'I9') is cheking
# Arc ('G8', 'I9') is cheking
# Arc ('G9', 'I9') is cheking
# Arc ('H7', 'I9') is cheking
# Arc ('H8', 'I9') is cheking
# Arc ('H9', 'I9') is cheking
# Arc ('I1', 'I9') is cheking
# Arc ('I3', 'I9') is cheking
# Arc ('I4', 'I9') is cheking
# Arc ('I5', 'I9') is cheking
# Arc ('I6', 'I9') is cheking
# Arc ('I7', 'I9') is cheking
# Arc ('I8', 'I9') is cheking
# Arc ('A9', 'I9') is cheking
# Arc ('B9', 'I9') is cheking
# Arc ('C9', 'I9') is cheking
# Arc ('D9', 'I9') is cheking
# Arc ('E9', 'I9') is cheking
# Arc ('F9', 'I9') is cheking
# Arc ('G7', 'I9') is cheking
# Arc ('G8', 'I9') is cheking
# Arc ('G9', 'I9') is cheking
# Arc ('H7', 'I9') is cheking
# Arc ('H8', 'I9') is cheking
# Arc ('H9', 'I9') is cheking
# Arc ('I1', 'I9') is cheking
# Arc ('I2', 'I9') is cheking
# Arc ('I3', 'I9') is cheking
# Arc ('I4', 'I9') is cheking
# Arc ('I5', 'I9') is cheking
# Arc ('I6', 'I9') is cheking
# Arc ('I7', 'I9') is cheking
# Arc ('A1', 'B2') is cheking
# Arc ('A2', 'B2') is cheking
# Arc ('A3', 'B2') is cheking
# Arc ('B1', 'B2') is cheking
# Arc ('B3', 'B2') is cheking
# Arc ('B4', 'B2') is cheking
# Arc ('B5', 'B2') is cheking
# Arc ('B6', 'B2') is cheking
# Arc ('B7', 'B2') is cheking
# Arc ('B8', 'B2') is cheking
# Arc ('B9', 'B2') is cheking
# Arc ('C1', 'B2') is cheking
# Arc ('C2', 'B2') is cheking
# Arc ('D2', 'B2') is cheking
# Arc ('E2', 'B2') is cheking
# Arc ('F2', 'B2') is cheking
# Arc ('G2', 'B2') is cheking
# Arc ('H2', 'B2') is cheking
# Arc ('I2', 'B2') is cheking
# Arc ('A4', 'B5') is cheking
# Arc ('A5', 'B5') is cheking
# Arc ('A6', 'B5') is cheking
# Arc ('B1', 'B5') is cheking
# Arc ('B2', 'B5') is cheking
# Arc ('B3', 'B5') is cheking
# Arc ('B4', 'B5') is cheking
# Arc ('B6', 'B5') is cheking
# Arc ('B7', 'B5') is cheking
# Arc ('B8', 'B5') is cheking
# Arc ('B9', 'B5') is cheking
# Arc ('C4', 'B5') is cheking
# Arc ('C5', 'B5') is cheking
# Arc ('C6', 'B5') is cheking
# Arc ('C7', 'B5') is cheking
# Arc ('D5', 'B5') is cheking
# Arc ('E2', 'B5') is cheking
# Arc ('E5', 'B5') is cheking
# Arc ('E8', 'B5') is cheking
# Arc ('F5', 'B5') is cheking
# Arc ('G3', 'B5') is cheking
# Arc ('G5', 'B5') is cheking
# Arc ('G7', 'B5') is cheking
# Arc ('H5', 'B5') is cheking
# Arc ('I5', 'B5') is cheking
# Arc ('A1', 'C1') is cheking
# Arc ('A2', 'C1') is cheking
# Arc ('A3', 'C1') is cheking
# Arc ('B1', 'C1') is cheking
# Arc ('B2', 'C1') is cheking
# Arc ('B3', 'C1') is cheking
# Arc ('C2', 'C1') is cheking
# Arc ('C4', 'C1') is cheking
# Arc ('C5', 'C1') is cheking
# Arc ('C6', 'C1') is cheking
# Arc ('C7', 'C1') is cheking
# Arc ('C8', 'C1') is cheking
# Arc ('C9', 'C1') is cheking
# Arc ('D1', 'C1') is cheking
# Arc ('E1', 'C1') is cheking
# Arc ('F1', 'C1') is cheking
# Arc ('G1', 'C1') is cheking
# Arc ('H1', 'C1') is cheking
# Arc ('I1', 'C1') is cheking
# (True, 25334)

# %%
for var in basicSudokuCSP.variables:
    print(var, basicSudokuCSP.curr_domains[var])
# Out:
# A1 [2, 4, 5, 7]
# A2 [1]
# A3 [5, 7]
# A4 [2, 7, 8, 9]
# A5 [2, 4, 8]
# A6 [2, 4, 7, 9]
# A7 [3, 4, 9]
# A8 [6]
# A9 [2, 3, 4, 8, 9]
# B1 [3]
# B2 [4, 7]
# B3 [9]
# B4 [2, 7, 8]
# B5 [2, 4, 8]
# B6 [2, 4, 6, 7]
# B7 [1]
# B8 [2, 4]
# B9 [5]
# C1 [2, 4]
# C2 [8]
# C3 [6]
# C4 [3]
# C5 [1, 2, 4]
# C6 [5]
# C7 [4, 9]
# C8 [7]
# C9 [2, 4, 9]
# D1 [1, 4, 5, 6]
# D2 [4, 5, 6, 9]
# D3 [2]
# D4 [1, 5]
# D5 [7]
# D6 [3, 4]
# D7 [8]
# D8 [1, 3, 4, 5]
# D9 [3, 4, 6, 9]
# E1 [1, 4, 5, 7]
# E2 [4, 5, 7, 9]
# E3 [1, 3, 5, 7]
# E4 [6]
# E5 [1, 2, 3, 4, 5]
# E6 [8]
# E7 [3, 4, 5, 7, 9]
# E8 [1, 3, 4, 5]
# E9 [3, 4, 7, 9]
# F1 [1, 4, 5, 6, 7]
# F2 [4, 5, 6, 7]
# F3 [8]
# F4 [1, 5]
# F5 [9]
# F6 [3, 4]
# F7 [2]
# F8 [1, 3, 4, 5]
# F9 [3, 4, 6, 7]
# G1 [5, 6, 7, 8]
# G2 [2]
# G3 [5, 7]
# G4 [4]
# G5 [3, 5, 6, 8]
# G6 [1]
# G7 [3, 5, 7]
# G8 [9]
# G9 [3, 7]
# H1 [9]
# H2 [5, 7]
# H3 [4]
# H4 [2, 5, 7, 8]
# H5 [2, 3, 5, 8]
# H6 [2, 3, 7]
# H7 [6]
# H8 [2, 3, 5]
# H9 [1]
# I1 [1, 5, 6, 7]
# I2 [3]
# I3 [1, 5, 7]
# I4 [2, 5, 7, 9]
# I5 [2, 5, 6]
# I6 [2, 6, 7, 9]
# I7 [4, 5, 7]
# I8 [8]
# I9 [2, 4, 7]

# %%
backtracking_search(basicSudokuCSP)
# Out:
# testing Variable A1 = 2
#   Total conflicts for A1 = 2: 0
#
# testing Variable A2 = 1
#   Checking A2(1) against A1(2) → conflict=True
#   Total conflicts for A2 = 1: 0
#
# testing Variable A3 = 5
#   Checking A3(5) against A1(2) → conflict=True
#   Checking A3(5) against A2(1) → conflict=True
#   Total conflicts for A3 = 5: 0
#
# testing Variable A4 = 2
#   Checking A4(2) against A1(2) → conflict=False
#   Checking A4(2) against A2(1) → conflict=True
#   Checking A4(2) against A3(5) → conflict=True
#   Total conflicts for A4 = 2: 1
#
# testing Variable A4 = 7
#   Checking A4(7) against A1(2) → conflict=True
#   Checking A4(7) against A2(1) → conflict=True
#   Checking A4(7) against A3(5) → conflict=True
#   Total conflicts for A4 = 7: 0
#
# testing Variable A5 = 2
#   Checking A5(2) against A1(2) → conflict=False
#   Checking A5(2) against A2(1) → conflict=True
#   Checking A5(2) against A3(5) → conflict=True
#   Checking A5(2) against A4(7) → conflict=True
#   Total conflicts for A5 = 2: 1
#
# testing Variable A5 = 4
#   Checking A5(4) against A1(2) → conflict=True
#   Checking A5(4) against A2(1) → conflict=True
#   Checking A5(4) against A3(5) → conflict=True
#   Checking A5(4) against A4(7) → conflict=True
#   Total conflicts for A5 = 4: 0
#
# testing Variable A6 = 2
#   Checking A6(2) against A1(2) → conflict=False
#   Checking A6(2) against A2(1) → conflict=True
#   Checking A6(2) against A3(5) → conflict=True
#   Checking A6(2) against A4(7) → conflict=True
#   Checking A6(2) against A5(4) → conflict=True
#   Total conflicts for A6 = 2: 1
#
# testing Variable A6 = 4
#   Checking A6(4) against A1(2) → conflict=True
#   Checking A6(4) against A2(1) → conflict=True
#   Checking A6(4) against A3(5) → conflict=True
#   Checking A6(4) against A4(7) → conflict=True
#   Checking A6(4) against A5(4) → conflict=False
#   Total conflicts for A6 = 4: 1
#
# testing Variable A6 = 7
#   Checking A6(7) against A1(2) → conflict=True
#   Checking A6(7) against A2(1) → conflict=True
#   Checking A6(7) against A3(5) → conflict=True
#   Checking A6(7) against A4(7) → conflict=False
#   Checking A6(7) against A5(4) → conflict=True
#   Total conflicts for A6 = 7: 1
#
# testing Variable A6 = 9
#   Checking A6(9) against A1(2) → conflict=True
#   Checking A6(9) against A2(1) → conflict=True
#   Checking A6(9) against A3(5) → conflict=True
#   Checking A6(9) against A4(7) → conflict=True
#   Checking A6(9) against A5(4) → conflict=True
#   Total conflicts for A6 = 9: 0
#
# testing Variable A7 = 3
#   Checking A7(3) against A1(2) → conflict=True
#   Checking A7(3) against A2(1) → conflict=True
#   Checking A7(3) against A3(5) → conflict=True
#   Checking A7(3) against A4(7) → conflict=True
#   Checking A7(3) against A5(4) → conflict=True
#   Checking A7(3) against A6(9) → conflict=True
#   Total conflicts for A7 = 3: 0
#
# testing Variable A8 = 6
#   Checking A8(6) against A1(2) → conflict=True
#   Checking A8(6) against A2(1) → conflict=True
#   Checking A8(6) against A3(5) → conflict=True
#   Checking A8(6) against A4(7) → conflict=True
#   Checking A8(6) against A5(4) → conflict=True
#   Checking A8(6) against A6(9) → conflict=True
#   Checking A8(6) against A7(3) → conflict=True
#   Total conflicts for A8 = 6: 0
#
# testing Variable A9 = 2
#   Checking A9(2) against A1(2) → conflict=False
#   Checking A9(2) against A2(1) → conflict=True
#   Checking A9(2) against A3(5) → conflict=True
#   Checking A9(2) against A4(7) → conflict=True
#   Checking A9(2) against A5(4) → conflict=True
#   Checking A9(2) against A6(9) → conflict=True
#   Checking A9(2) against A7(3) → conflict=True
#   Checking A9(2) against A8(6) → conflict=True
#   Total conflicts for A9 = 2: 1
#
# testing Variable A9 = 3
#   Checking A9(3) against A1(2) → conflict=True
#   Checking A9(3) against A2(1) → conflict=True
#   Checking A9(3) against A3(5) → conflict=True
#   Checking A9(3) against A4(7) → conflict=True
#   Checking A9(3) against A5(4) → conflict=True
#   Checking A9(3) against A6(9) → conflict=True
#   Checking A9(3) against A7(3) → conflict=False
#   Checking A9(3) against A8(6) → conflict=True
#   Total conflicts for A9 = 3: 1
#
# testing Variable A9 = 4
#   Checking A9(4) against A1(2) → conflict=True
#   Checking A9(4) against A2(1) → conflict=True
#   Checking A9(4) against A3(5) → conflict=True
#   Checking A9(4) against A4(7) → conflict=True
#   Checking A9(4) against A5(4) → conflict=False
#   Checking A9(4) against A6(9) → conflict=True
#   Checking A9(4) against A7(3) → conflict=True
#   Checking A9(4) against A8(6) → conflict=True
#   Total conflicts for A9 = 4: 1
#
# testing Variable A9 = 8
#   Checking A9(8) against A1(2) → conflict=True
#   Checking A9(8) against A2(1) → conflict=True
#   Checking A9(8) against A3(5) → conflict=True
#   Checking A9(8) against A4(7) → conflict=True
#   Checking A9(8) against A5(4) → conflict=True
#   Checking A9(8) against A6(9) → conflict=True
#   Checking A9(8) against A7(3) → conflict=True
#   Checking A9(8) against A8(6) → conflict=True
#   Total conflicts for A9 = 8: 0
#
# testing Variable B1 = 3
#   Checking B1(3) against A1(2) → conflict=True
#   Checking B1(3) against A2(1) → conflict=True
#   Checking B1(3) against A3(5) → conflict=True
#   Total conflicts for B1 = 3: 0
#
# testing Variable B2 = 4
#   Checking B2(4) against A1(2) → conflict=True
#   Checking B2(4) against A2(1) → conflict=True
#   Checking B2(4) against A3(5) → conflict=True
#   Checking B2(4) against B1(3) → conflict=True
#   Total conflicts for B2 = 4: 0
#
# testing Variable B3 = 9
#   Checking B3(9) against A1(2) → conflict=True
#   Checking B3(9) against A2(1) → conflict=True
#   Checking B3(9) against A3(5) → conflict=True
#   Checking B3(9) against B1(3) → conflict=True
#   Checking B3(9) against B2(4) → conflict=True
#   Total conflicts for B3 = 9: 0
#
# testing Variable B4 = 2
#   Checking B4(2) against A4(7) → conflict=True
#   Checking B4(2) against A5(4) → conflict=True
#   Checking B4(2) against A6(9) → conflict=True
#   Checking B4(2) against B1(3) → conflict=True
#   Checking B4(2) against B2(4) → conflict=True
#   Checking B4(2) against B3(9) → conflict=True
#   Total conflicts for B4 = 2: 0
#
# testing Variable B5 = 2
#   Checking B5(2) against A4(7) → conflict=True
#   Checking B5(2) against A5(4) → conflict=True
#   Checking B5(2) against A6(9) → conflict=True
#   Checking B5(2) against B1(3) → conflict=True
#   Checking B5(2) against B2(4) → conflict=True
#   Checking B5(2) against B3(9) → conflict=True
#   Checking B5(2) against B4(2) → conflict=False
#   Total conflicts for B5 = 2: 1
#
# testing Variable B5 = 4
#   Checking B5(4) against A4(7) → conflict=True
#   Checking B5(4) against A5(4) → conflict=False
#   Checking B5(4) against A6(9) → conflict=True
#   Checking B5(4) against B1(3) → conflict=True
#   Checking B5(4) against B2(4) → conflict=False
#   Checking B5(4) against B3(9) → conflict=True
#   Checking B5(4) against B4(2) → conflict=True
#   Total conflicts for B5 = 4: 2
#
# testing Variable B5 = 8
#   Checking B5(8) against A4(7) → conflict=True
#   Checking B5(8) against A5(4) → conflict=True
#   Checking B5(8) against A6(9) → conflict=True
#   Checking B5(8) against B1(3) → conflict=True
#   Checking B5(8) against B2(4) → conflict=True
#   Checking B5(8) against B3(9) → conflict=True
#   Checking B5(8) against B4(2) → conflict=True
#   Total conflicts for B5 = 8: 0
#
# testing Variable B6 = 2
#   Checking B6(2) against A4(7) → conflict=True
#   Checking B6(2) against A5(4) → conflict=True
#   Checking B6(2) against A6(9) → conflict=True
#   Checking B6(2) against B1(3) → conflict=True
#   Checking B6(2) against B2(4) → conflict=True
#   Checking B6(2) against B3(9) → conflict=True
#   Checking B6(2) against B4(2) → conflict=False
#   Checking B6(2) against B5(8) → conflict=True
#   Total conflicts for B6 = 2: 1
#
# testing Variable B6 = 4
#   Checking B6(4) against A4(7) → conflict=True
#   Checking B6(4) against A5(4) → conflict=False
#   Checking B6(4) against A6(9) → conflict=True
#   Checking B6(4) against B1(3) → conflict=True
#   Checking B6(4) against B2(4) → conflict=False
#   Checking B6(4) against B3(9) → conflict=True
#   Checking B6(4) against B4(2) → conflict=True
#   Checking B6(4) against B5(8) → conflict=True
#   Total conflicts for B6 = 4: 2
#
# testing Variable B6 = 6
#   Checking B6(6) against A4(7) → conflict=True
#   Checking B6(6) against A5(4) → conflict=True
#   Checking B6(6) against A6(9) → conflict=True
#   Checking B6(6) against B1(3) → conflict=True
#   Checking B6(6) against B2(4) → conflict=True
#   Checking B6(6) against B3(9) → conflict=True
#   Checking B6(6) against B4(2) → conflict=True
#   Checking B6(6) against B5(8) → conflict=True
#   Total conflicts for B6 = 6: 0
#
# testing Variable B7 = 1
#   Checking B7(1) against A7(3) → conflict=True
#   Checking B7(1) against A8(6) → conflict=True
#   Checking B7(1) against A9(8) → conflict=True
#   Checking B7(1) against B1(3) → conflict=True
#   Checking B7(1) against B2(4) → conflict=True
#   Checking B7(1) against B3(9) → conflict=True
#   Checking B7(1) against B4(2) → conflict=True
#   Checking B7(1) against B5(8) → conflict=True
#   Checking B7(1) against B6(6) → conflict=True
#   Total conflicts for B7 = 1: 0
#
# testing Variable B8 = 2
#   Checking B8(2) against A7(3) → conflict=True
#   Checking B8(2) against A8(6) → conflict=True
#   Checking B8(2) against A9(8) → conflict=True
#   Checking B8(2) against B1(3) → conflict=True
#   Checking B8(2) against B2(4) → conflict=True
#   Checking B8(2) against B3(9) → conflict=True
#   Checking B8(2) against B4(2) → conflict=False
#   Checking B8(2) against B5(8) → conflict=True
#   Checking B8(2) against B6(6) → conflict=True
#   Checking B8(2) against B7(1) → conflict=True
#   Total conflicts for B8 = 2: 1
#
# testing Variable B8 = 4
#   Checking B8(4) against A7(3) → conflict=True
#   Checking B8(4) against A8(6) → conflict=True
#   Checking B8(4) against A9(8) → conflict=True
#   Checking B8(4) against B1(3) → conflict=True
#   Checking B8(4) against B2(4) → conflict=False
#   Checking B8(4) against B3(9) → conflict=True
#   Checking B8(4) against B4(2) → conflict=True
#   Checking B8(4) against B5(8) → conflict=True
#   Checking B8(4) against B6(6) → conflict=True
#   Checking B8(4) against B7(1) → conflict=True
#   Total conflicts for B8 = 4: 1
#
# testing Variable B6 = 7
#   Checking B6(7) against A4(7) → conflict=False
#   Checking B6(7) against A5(4) → conflict=True
#   Checking B6(7) against A6(9) → conflict=True
#   Checking B6(7) against B1(3) → conflict=True
#   Checking B6(7) against B2(4) → conflict=True
#   Checking B6(7) against B3(9) → conflict=True
#   Checking B6(7) against B4(2) → conflict=True
#   Checking B6(7) against B5(8) → conflict=True
#   Total conflicts for B6 = 7: 1
#
# testing Variable B4 = 7
#   Checking B4(7) against A4(7) → conflict=False
#   Checking B4(7) against A5(4) → conflict=True
#   Checking B4(7) against A6(9) → conflict=True
#   Checking B4(7) against B1(3) → conflict=True
#   Checking B4(7) against B2(4) → conflict=True
#   Checking B4(7) against B3(9) → conflict=True
#   Total conflicts for B4 = 7: 1
#
# testing Variable B4 = 8
#   Checking B4(8) against A4(7) → conflict=True
#   Checking B4(8) against A5(4) → conflict=True
#   Checking B4(8) against A6(9) → conflict=True
#   Checking B4(8) against B1(3) → conflict=True
#   Checking B4(8) against B2(4) → conflict=True
#   Checking B4(8) against B3(9) → conflict=True
#   Total conflicts for B4 = 8: 0
#
# testing Variable B5 = 2
#   Checking B5(2) against A4(7) → conflict=True
#   Checking B5(2) against A5(4) → conflict=True
#   Checking B5(2) against A6(9) → conflict=True
#   Checking B5(2) against B1(3) → conflict=True
#   Checking B5(2) against B2(4) → conflict=True
#   Checking B5(2) against B3(9) → conflict=True
#   Checking B5(2) against B4(8) → conflict=True
#   Total conflicts for B5 = 2: 0
#
# testing Variable B6 = 2
#   Checking B6(2) against A4(7) → conflict=True
#   Checking B6(2) against A5(4) → conflict=True
#   Checking B6(2) against A6(9) → conflict=True
#   Checking B6(2) against B1(3) → conflict=True
#   Checking B6(2) against B2(4) → conflict=True
#   Checking B6(2) against B3(9) → conflict=True
#   Checking B6(2) against B4(8) → conflict=True
#   Checking B6(2) against B5(2) → conflict=False
#   Total conflicts for B6 = 2: 1
#
# testing Variable B6 = 4
#   Checking B6(4) against A4(7) → conflict=True
#   Checking B6(4) against A5(4) → conflict=False
#   Checking B6(4) against A6(9) → conflict=True
#   Checking B6(4) against B1(3) → conflict=True
#   Checking B6(4) against B2(4) → conflict=False
#   Checking B6(4) against B3(9) → conflict=True
#   Checking B6(4) against B4(8) → conflict=True
#   Checking B6(4) against B5(2) → conflict=True
#   Total conflicts for B6 = 4: 2
#
# testing Variable B6 = 6
#   Checking B6(6) against A4(7) → conflict=True
#   Checking B6(6) against A5(4) → conflict=True
#   Checking B6(6) against A6(9) → conflict=True
#   Checking B6(6) against B1(3) → conflict=True
#   Checking B6(6) against B2(4) → conflict=True
#   Checking B6(6) against B3(9) → conflict=True
#   Checking B6(6) against B4(8) → conflict=True
#   Checking B6(6) against B5(2) → conflict=True
#   Total conflicts for B6 = 6: 0
#
# testing Variable B7 = 1
#   Checking B7(1) against A7(3) → conflict=True
#   Checking B7(1) against A8(6) → conflict=True
#   Checking B7(1) against A9(8) → conflict=True
#   Checking B7(1) against B1(3) → conflict=True
#   Checking B7(1) against B2(4) → conflict=True
#   Checking B7(1) against B3(9) → conflict=True
#   Checking B7(1) against B4(8) → conflict=True
#   Checking B7(1) against B5(2) → conflict=True
#   Checking B7(1) against B6(6) → conflict=True
#   Total conflicts for B7 = 1: 0
#
# testing Variable B8 = 2
#   Checking B8(2) against A7(3) → conflict=True
#   Checking B8(2) against A8(6) → conflict=True
#   Checking B8(2) against A9(8) → conflict=True
#   Checking B8(2) against B1(3) → conflict=True
#   Checking B8(2) against B2(4) → conflict=True
#   Checking B8(2) against B3(9) → conflict=True
#   Checking B8(2) against B4(8) → conflict=True
#   Checking B8(2) against B5(2) → conflict=False
#   Checking B8(2) against B6(6) → conflict=True
#   Checking B8(2) against B7(1) → conflict=True
#   Total conflicts for B8 = 2: 1
#
# testing Variable B8 = 4
#   Checking B8(4) against A7(3) → conflict=True
#   Checking B8(4) against A8(6) → conflict=True
#   Checking B8(4) against A9(8) → conflict=True
#   Checking B8(4) against B1(3) → conflict=True
#   Checking B8(4) against B2(4) → conflict=False
#   Checking B8(4) against B3(9) → conflict=True
#   Checking B8(4) against B4(8) → conflict=True
#   Checking B8(4) against B5(2) → conflict=True
#   Checking B8(4) against B6(6) → conflict=True
#   Checking B8(4) against B7(1) → conflict=True
#   Total conflicts for B8 = 4: 1
#
# testing Variable B6 = 7
#   Checking B6(7) against A4(7) → conflict=False
#   Checking B6(7) against A5(4) → conflict=True
#   Checking B6(7) against A6(9) → conflict=True
#   Checking B6(7) against B1(3) → conflict=True
#   Checking B6(7) against B2(4) → conflict=True
#   Checking B6(7) against B3(9) → conflict=True
#   Checking B6(7) against B4(8) → conflict=True
#   Checking B6(7) against B5(2) → conflict=True
#   Total conflicts for B6 = 7: 1
#
# testing Variable B5 = 4
#   Checking B5(4) against A4(7) → conflict=True
#   Checking B5(4) against A5(4) → conflict=False
#   Checking B5(4) against A6(9) → conflict=True
#   Checking B5(4) against B1(3) → conflict=True
#   Checking B5(4) against B2(4) → conflict=False
#   Checking B5(4) against B3(9) → conflict=True
#   Checking B5(4) against B4(8) → conflict=True
#   Total conflicts for B5 = 4: 2
#
# testing Variable B5 = 8
#   Checking B5(8) against A4(7) → conflict=True
#   Checking B5(8) against A5(4) → conflict=True
#   Checking B5(8) against A6(9) → conflict=True
#   Checking B5(8) against B1(3) → conflict=True
#   Checking B5(8) against B2(4) → conflict=True
#   Checking B5(8) against B3(9) → conflict=True
#   Checking B5(8) against B4(8) → conflict=False
#   Total conflicts for B5 = 8: 1
#
# testing Variable B2 = 7
#   Checking B2(7) against A1(2) → conflict=True
#   Checking B2(7) against A2(1) → conflict=True
#   Checking B2(7) against A3(5) → conflict=True
#   Checking B2(7) against B1(3) → conflict=True
#   Total conflicts for B2 = 7: 0
#
# testing Variable B3 = 9
#   Checking B3(9) against A1(2) → conflict=True
#   Checking B3(9) against A2(1) → conflict=True
#   Checking B3(9) against A3(5) → conflict=True
#   Checking B3(9) against B1(3) → conflict=True
#   Checking B3(9) against B2(7) → conflict=True
#   Total conflicts for B3 = 9: 0
#
# testing Variable B4 = 2
#   Checking B4(2) against A4(7) → conflict=True
#   Checking B4(2) against A5(4) → conflict=True
#   Checking B4(2) against A6(9) → conflict=True
#   Checking B4(2) against B1(3) → conflict=True
#   Checking B4(2) against B2(7) → conflict=True
#   Checking B4(2) against B3(9) → conflict=True
#   Total conflicts for B4 = 2: 0
#
# testing Variable B5 = 2
#   Checking B5(2) against A4(7) → conflict=True
#   Checking B5(2) against A5(4) → conflict=True
#   Checking B5(2) against A6(9) → conflict=True
#   Checking B5(2) against B1(3) → conflict=True
#   Checking B5(2) against B2(7) → conflict=True
#   Checking B5(2) against B3(9) → conflict=True
#   Checking B5(2) against B4(2) → conflict=False
#   Total conflicts for B5 = 2: 1
#
# testing Variable B5 = 4
#   Checking B5(4) against A4(7) → conflict=True
#   Checking B5(4) against A5(4) → conflict=False
#   Checking B5(4) against A6(9) → conflict=True
#   Checking B5(4) against B1(3) → conflict=True
#   Checking B5(4) against B2(7) → conflict=True
#   Checking B5(4) against B3(9) → conflict=True
#   Checking B5(4) against B4(2) → conflict=True
#   Total conflicts for B5 = 4: 1
#
# testing Variable B5 = 8
#   Checking B5(8) against A4(7) → conflict=True
#   Checking B5(8) against A5(4) → conflict=True
#   Checking B5(8) against A6(9) → conflict=True
#   Checking B5(8) against B1(3) → conflict=True
#   Checking B5(8) against B2(7) → conflict=True
#   Checking B5(8) against B3(9) → conflict=True
#   Checking B5(8) against B4(2) → conflict=True
#   Total conflicts for B5 = 8: 0
#
# testing Variable B6 = 2
#   Checking B6(2) against A4(7) → conflict=True
#   Checking B6(2) against A5(4) → conflict=True
#   Checking B6(2) against A6(9) → conflict=True
#   Checking B6(2) against B1(3) → conflict=True
#   Checking B6(2) against B2(7) → conflict=True
#   Checking B6(2) against B3(9) → conflict=True
#   Checking B6(2) against B4(2) → conflict=False
#   Checking B6(2) against B5(8) → conflict=True
#   Total conflicts for B6 = 2: 1
#
# testing Variable B6 = 4
#   Checking B6(4) against A4(7) → conflict=True
#   Checking B6(4) against A5(4) → conflict=False
#   Checking B6(4) against A6(9) → conflict=True
#   Checking B6(4) against B1(3) → conflict=True
#   Checking B6(4) against B2(7) → conflict=True
#   Checking B6(4) against B3(9) → conflict=True
#   Checking B6(4) against B4(2) → conflict=True
#   Checking B6(4) against B5(8) → conflict=True
#   Total conflicts for B6 = 4: 1
#
# testing Variable B6 = 6
#   Checking B6(6) against A4(7) → conflict=True
#   Checking B6(6) against A5(4) → conflict=True
#   Checking B6(6) against A6(9) → conflict=True
#   Checking B6(6) against B1(3) → conflict=True
#   Checking B6(6) against B2(7) → conflict=True
#   Checking B6(6) against B3(9) → conflict=True
#   Checking B6(6) against B4(2) → conflict=True
#   Checking B6(6) against B5(8) → conflict=True
#   Total conflicts for B6 = 6: 0
#
# testing Variable B7 = 1
#   Checking B7(1) against A7(3) → conflict=True
#   Checking B7(1) against A8(6) → conflict=True
#   Checking B7(1) against A9(8) → conflict=True
#   Checking B7(1) against B1(3) → conflict=True
#   Checking B7(1) against B2(7) → conflict=True
#   Checking B7(1) against B3(9) → conflict=True
#   Checking B7(1) against B4(2) → conflict=True
#   Checking B7(1) against B5(8) → conflict=True
#   Checking B7(1) against B6(6) → conflict=True
#   Total conflicts for B7 = 1: 0
#
# testing Variable B8 = 2
#   Checking B8(2) against A7(3) → conflict=True
#   Checking B8(2) against A8(6) → conflict=True
#   Checking B8(2) against A9(8) → conflict=True
#   Checking B8(2) against B1(3) → conflict=True
#   Checking B8(2) against B2(7) → conflict=True
#   Checking B8(2) against B3(9) → conflict=True
#   Checking B8(2) against B4(2) → conflict=False
#   Checking B8(2) against B5(8) → conflict=True
#   Checking B8(2) against B6(6) → conflict=True
#   Checking B8(2) against B7(1) → conflict=True
#   Total conflicts for B8 = 2: 1
#
# testing Variable B8 = 4
#   Checking B8(4) against A7(3) → conflict=True
#   Checking B8(4) against A8(6) → conflict=True
#   Checking B8(4) against A9(8) → conflict=True
#   Checking B8(4) against B1(3) → conflict=True
#   Checking B8(4) against B2(7) → conflict=True
#   Checking B8(4) against B3(9) → conflict=True
#   Checking B8(4) against B4(2) → conflict=True
#   Checking B8(4) against B5(8) → conflict=True
#   Checking B8(4) against B6(6) → conflict=True
#   Checking B8(4) against B7(1) → conflict=True
#   Total conflicts for B8 = 4: 0
#
# testing Variable B9 = 5
#   Checking B9(5) against A7(3) → conflict=True
#   Checking B9(5) against A8(6) → conflict=True
#   Checking B9(5) against A9(8) → conflict=True
#   Checking B9(5) against B1(3) → conflict=True
#   Checking B9(5) against B2(7) → conflict=True
#   Checking B9(5) against B3(9) → conflict=True
#   Checking B9(5) against B4(2) → conflict=True
#   Checking B9(5) against B5(8) → conflict=True
#   Checking B9(5) against B6(6) → conflict=True
#   Checking B9(5) against B7(1) → conflict=True
#   Checking B9(5) against B8(4) → conflict=True
#   Total conflicts for B9 = 5: 0
#
# testing Variable C1 = 2
#   Checking C1(2) against A1(2) → conflict=False
#   Checking C1(2) against A2(1) → conflict=True
#   Checking C1(2) against A3(5) → conflict=True
#   Checking C1(2) against B1(3) → conflict=True
#   Checking C1(2) against B2(7) → conflict=True
#   Checking C1(2) against B3(9) → conflict=True
#   Total conflicts for C1 = 2: 1
#
# testing Variable C1 = 4
#   Checking C1(4) against A1(2) → conflict=True
#   Checking C1(4) against A2(1) → conflict=True
#   Checking C1(4) against A3(5) → conflict=True
#   Checking C1(4) against B1(3) → conflict=True
#   Checking C1(4) against B2(7) → conflict=True
#   Checking C1(4) against B3(9) → conflict=True
#   Total conflicts for C1 = 4: 0
#
# testing Variable C2 = 8
#   Checking C2(8) against A1(2) → conflict=True
#   Checking C2(8) against A2(1) → conflict=True
#   Checking C2(8) against A3(5) → conflict=True
#   Checking C2(8) against B1(3) → conflict=True
#   Checking C2(8) against B2(7) → conflict=True
#   Checking C2(8) against B3(9) → conflict=True
#   Checking C2(8) against C1(4) → conflict=True
#   Total conflicts for C2 = 8: 0
#
# testing Variable C3 = 6
#   Checking C3(6) against A1(2) → conflict=True
#   Checking C3(6) against A2(1) → conflict=True
#   Checking C3(6) against A3(5) → conflict=True
#   Checking C3(6) against B1(3) → conflict=True
#   Checking C3(6) against B2(7) → conflict=True
#   Checking C3(6) against B3(9) → conflict=True
#   Checking C3(6) against B5(8) → conflict=True
#   Checking C3(6) against C1(4) → conflict=True
#   Checking C3(6) against C2(8) → conflict=True
#   Total conflicts for C3 = 6: 0
#
# testing Variable C4 = 3
#   Checking C4(3) against A4(7) → conflict=True
#   Checking C4(3) against A5(4) → conflict=True
#   Checking C4(3) against A6(9) → conflict=True
#   Checking C4(3) against B4(2) → conflict=True
#   Checking C4(3) against B5(8) → conflict=True
#   Checking C4(3) against B6(6) → conflict=True
#   Checking C4(3) against C1(4) → conflict=True
#   Checking C4(3) against C2(8) → conflict=True
#   Checking C4(3) against C3(6) → conflict=True
#   Total conflicts for C4 = 3: 0
#
# testing Variable C5 = 1
#   Checking C5(1) against A4(7) → conflict=True
#   Checking C5(1) against A5(4) → conflict=True
#   Checking C5(1) against A6(9) → conflict=True
#   Checking C5(1) against B4(2) → conflict=True
#   Checking C5(1) against B5(8) → conflict=True
#   Checking C5(1) against B6(6) → conflict=True
#   Checking C5(1) against C1(4) → conflict=True
#   Checking C5(1) against C2(8) → conflict=True
#   Checking C5(1) against C3(6) → conflict=True
#   Checking C5(1) against C4(3) → conflict=True
#   Total conflicts for C5 = 1: 0
#
# testing Variable C6 = 5
#   Checking C6(5) against A4(7) → conflict=True
#   Checking C6(5) against A5(4) → conflict=True
#   Checking C6(5) against A6(9) → conflict=True
#   Checking C6(5) against B4(2) → conflict=True
#   Checking C6(5) against B5(8) → conflict=True
#   Checking C6(5) against B6(6) → conflict=True
#   Checking C6(5) against C1(4) → conflict=True
#   Checking C6(5) against C2(8) → conflict=True
#   Checking C6(5) against C3(6) → conflict=True
#   Checking C6(5) against C4(3) → conflict=True
#   Checking C6(5) against C5(1) → conflict=True
#   Total conflicts for C6 = 5: 0
#
# testing Variable C7 = 4
#   Checking C7(4) against A7(3) → conflict=True
#   Checking C7(4) against A8(6) → conflict=True
#   Checking C7(4) against A9(8) → conflict=True
#   Checking C7(4) against B5(8) → conflict=True
#   Checking C7(4) against B7(1) → conflict=True
#   Checking C7(4) against B8(4) → conflict=False
#   Checking C7(4) against B9(5) → conflict=True
#   Checking C7(4) against C1(4) → conflict=False
#   Checking C7(4) against C2(8) → conflict=True
#   Checking C7(4) against C3(6) → conflict=True
#   Checking C7(4) against C4(3) → conflict=True
#   Checking C7(4) against C5(1) → conflict=True
#   Checking C7(4) against C6(5) → conflict=True
#   Total conflicts for C7 = 4: 2
#
# testing Variable C7 = 9
#   Checking C7(9) against A7(3) → conflict=True
#   Checking C7(9) against A8(6) → conflict=True
#   Checking C7(9) against A9(8) → conflict=True
#   Checking C7(9) against B5(8) → conflict=True
#   Checking C7(9) against B7(1) → conflict=True
#   Checking C7(9) against B8(4) → conflict=True
#   Checking C7(9) against B9(5) → conflict=True
#   Checking C7(9) against C1(4) → conflict=True
#   Checking C7(9) against C2(8) → conflict=True
#   Checking C7(9) against C3(6) → conflict=True
#   Checking C7(9) against C4(3) → conflict=True
#   Checking C7(9) against C5(1) → conflict=True
#   Checking C7(9) against C6(5) → conflict=True
#   Total conflicts for C7 = 9: 0
#
# testing Variable C8 = 7
#   Checking C8(7) against A7(3) → conflict=True
#   Checking C8(7) against A8(6) → conflict=True
#   Checking C8(7) against A9(8) → conflict=True
#   Checking C8(7) against B7(1) → conflict=True
#   Checking C8(7) against B8(4) → conflict=True
#   Checking C8(7) against B9(5) → conflict=True
#   Checking C8(7) against C1(4) → conflict=True
#   Checking C8(7) against C2(8) → conflict=True
#   Checking C8(7) against C3(6) → conflict=True
#   Checking C8(7) against C4(3) → conflict=True
#   Checking C8(7) against C5(1) → conflict=True
#   Checking C8(7) against C6(5) → conflict=True
#   Checking C8(7) against C7(9) → conflict=True
#   Total conflicts for C8 = 7: 0
#
# testing Variable C9 = 2
#   Checking C9(2) against A7(3) → conflict=True
#   Checking C9(2) against A8(6) → conflict=True
#   Checking C9(2) against A9(8) → conflict=True
#   Checking C9(2) against B7(1) → conflict=True
#   Checking C9(2) against B8(4) → conflict=True
#   Checking C9(2) against B9(5) → conflict=True
#   Checking C9(2) against C1(4) → conflict=True
#   Checking C9(2) against C2(8) → conflict=True
#   Checking C9(2) against C3(6) → conflict=True
#   Checking C9(2) against C4(3) → conflict=True
#   Checking C9(2) against C5(1) → conflict=True
#   Checking C9(2) against C6(5) → conflict=True
#   Checking C9(2) against C7(9) → conflict=True
#   Checking C9(2) against C8(7) → conflict=True
#   Total conflicts for C9 = 2: 0
#
# testing Variable D1 = 1
#   Checking D1(1) against A1(2) → conflict=True
#   Checking D1(1) against B1(3) → conflict=True
#   Checking D1(1) against C1(4) → conflict=True
#   Total conflicts for D1 = 1: 0
#
# testing Variable D2 = 4
#   Checking D2(4) against A2(1) → conflict=True
#   Checking D2(4) against B2(7) → conflict=True
#   Checking D2(4) against C2(8) → conflict=True
#   Checking D2(4) against D1(1) → conflict=True
#   Total conflicts for D2 = 4: 0
#
# testing Variable D3 = 2
#   Checking D3(2) against A3(5) → conflict=True
#   Checking D3(2) against B3(9) → conflict=True
#   Checking D3(2) against C3(6) → conflict=True
#   Checking D3(2) against D1(1) → conflict=True
#   Checking D3(2) against D2(4) → conflict=True
#   Total conflicts for D3 = 2: 0
#
# testing Variable D4 = 1
#   Checking D4(1) against A4(7) → conflict=True
#   Checking D4(1) against B4(2) → conflict=True
#   Checking D4(1) against C4(3) → conflict=True
#   Checking D4(1) against D1(1) → conflict=False
#   Checking D4(1) against D2(4) → conflict=True
#   Checking D4(1) against D3(2) → conflict=True
#   Total conflicts for D4 = 1: 1
#
# testing Variable D4 = 5
#   Checking D4(5) against A4(7) → conflict=True
#   Checking D4(5) against B4(2) → conflict=True
#   Checking D4(5) against C4(3) → conflict=True
#   Checking D4(5) against D1(1) → conflict=True
#   Checking D4(5) against D2(4) → conflict=True
#   Checking D4(5) against D3(2) → conflict=True
#   Total conflicts for D4 = 5: 0
#
# testing Variable D5 = 7
#   Checking D5(7) against A5(4) → conflict=True
#   Checking D5(7) against B5(8) → conflict=True
#   Checking D5(7) against C5(1) → conflict=True
#   Checking D5(7) against D1(1) → conflict=True
#   Checking D5(7) against D2(4) → conflict=True
#   Checking D5(7) against D3(2) → conflict=True
#   Checking D5(7) against D4(5) → conflict=True
#   Total conflicts for D5 = 7: 0
#
# testing Variable D6 = 3
#   Checking D6(3) against A6(9) → conflict=True
#   Checking D6(3) against B6(6) → conflict=True
#   Checking D6(3) against C6(5) → conflict=True
#   Checking D6(3) against D1(1) → conflict=True
#   Checking D6(3) against D2(4) → conflict=True
#   Checking D6(3) against D3(2) → conflict=True
#   Checking D6(3) against D4(5) → conflict=True
#   Checking D6(3) against D5(7) → conflict=True
#   Total conflicts for D6 = 3: 0
#
# testing Variable D7 = 8
#   Checking D7(8) against A7(3) → conflict=True
#   Checking D7(8) against B7(1) → conflict=True
#   Checking D7(8) against C7(9) → conflict=True
#   Checking D7(8) against D1(1) → conflict=True
#   Checking D7(8) against D2(4) → conflict=True
#   Checking D7(8) against D3(2) → conflict=True
#   Checking D7(8) against D4(5) → conflict=True
#   Checking D7(8) against D5(7) → conflict=True
#   Checking D7(8) against D6(3) → conflict=True
#   Total conflicts for D7 = 8: 0
#
# testing Variable D8 = 1
#   Checking D8(1) against A8(6) → conflict=True
#   Checking D8(1) against B8(4) → conflict=True
#   Checking D8(1) against C8(7) → conflict=True
#   Checking D8(1) against D1(1) → conflict=False
#   Checking D8(1) against D2(4) → conflict=True
#   Checking D8(1) against D3(2) → conflict=True
#   Checking D8(1) against D4(5) → conflict=True
#   Checking D8(1) against D5(7) → conflict=True
#   Checking D8(1) against D6(3) → conflict=True
#   Checking D8(1) against D7(8) → conflict=True
#   Total conflicts for D8 = 1: 1
#
# testing Variable D8 = 3
#   Checking D8(3) against A8(6) → conflict=True
#   Checking D8(3) against B8(4) → conflict=True
#   Checking D8(3) against C8(7) → conflict=True
#   Checking D8(3) against D1(1) → conflict=True
#   Checking D8(3) against D2(4) → conflict=True
#   Checking D8(3) against D3(2) → conflict=True
#   Checking D8(3) against D4(5) → conflict=True
#   Checking D8(3) against D5(7) → conflict=True
#   Checking D8(3) against D6(3) → conflict=False
#   Checking D8(3) against D7(8) → conflict=True
#   Total conflicts for D8 = 3: 1
#
# testing Variable D8 = 4
#   Checking D8(4) against A8(6) → conflict=True
#   Checking D8(4) against B8(4) → conflict=False
#   Checking D8(4) against C8(7) → conflict=True
#   Checking D8(4) against D1(1) → conflict=True
#   Checking D8(4) against D2(4) → conflict=False
#   Checking D8(4) against D3(2) → conflict=True
#   Checking D8(4) against D4(5) → conflict=True
#   Checking D8(4) against D5(7) → conflict=True
#   Checking D8(4) against D6(3) → conflict=True
#   Checking D8(4) against D7(8) → conflict=True
#   Total conflicts for D8 = 4: 2
#
# testing Variable D8 = 5
#   Checking D8(5) against A8(6) → conflict=True
#   Checking D8(5) against B8(4) → conflict=True
#   Checking D8(5) against C8(7) → conflict=True
#   Checking D8(5) against D1(1) → conflict=True
#   Checking D8(5) against D2(4) → conflict=True
#   Checking D8(5) against D3(2) → conflict=True
#   Checking D8(5) against D4(5) → conflict=False
#   Checking D8(5) against D5(7) → conflict=True
#   Checking D8(5) against D6(3) → conflict=True
#   Checking D8(5) against D7(8) → conflict=True
#   Total conflicts for D8 = 5: 1
#
# testing Variable D6 = 4
#   Checking D6(4) against A6(9) → conflict=True
#   Checking D6(4) against B6(6) → conflict=True
#   Checking D6(4) against C6(5) → conflict=True
#   Checking D6(4) against D1(1) → conflict=True
#   Checking D6(4) against D2(4) → conflict=False
#   Checking D6(4) against D3(2) → conflict=True
#   Checking D6(4) against D4(5) → conflict=True
#   Checking D6(4) against D5(7) → conflict=True
#   Total conflicts for D6 = 4: 1
#
# testing Variable D2 = 5
#   Checking D2(5) against A2(1) → conflict=True
#   Checking D2(5) against B2(7) → conflict=True
#   Checking D2(5) against C2(8) → conflict=True
#   Checking D2(5) against D1(1) → conflict=True
#   Total conflicts for D2 = 5: 0
#
# testing Variable D3 = 2
#   Checking D3(2) against A3(5) → conflict=True
#   Checking D3(2) against B3(9) → conflict=True
#   Checking D3(2) against C3(6) → conflict=True
#   Checking D3(2) against D1(1) → conflict=True
#   Checking D3(2) against D2(5) → conflict=True
#   Total conflicts for D3 = 2: 0
#
# testing Variable D4 = 1
#   Checking D4(1) against A4(7) → conflict=True
#   Checking D4(1) against B4(2) → conflict=True
#   Checking D4(1) against C4(3) → conflict=True
#   Checking D4(1) against D1(1) → conflict=False
#   Checking D4(1) against D2(5) → conflict=True
#   Checking D4(1) against D3(2) → conflict=True
#   Total conflicts for D4 = 1: 1
#
# testing Variable D4 = 5
#   Checking D4(5) against A4(7) → conflict=True
#   Checking D4(5) against B4(2) → conflict=True
#   Checking D4(5) against C4(3) → conflict=True
#   Checking D4(5) against D1(1) → conflict=True
#   Checking D4(5) against D2(5) → conflict=False
#   Checking D4(5) against D3(2) → conflict=True
#   Total conflicts for D4 = 5: 1
#
# testing Variable D2 = 6
#   Checking D2(6) against A2(1) → conflict=True
#   Checking D2(6) against B2(7) → conflict=True
#   Checking D2(6) against C2(8) → conflict=True
#   Checking D2(6) against D1(1) → conflict=True
#   Total conflicts for D2 = 6: 0
#
# testing Variable D3 = 2
#   Checking D3(2) against A3(5) → conflict=True
#   Checking D3(2) against B3(9) → conflict=True
#   Checking D3(2) against C3(6) → conflict=True
#   Checking D3(2) against D1(1) → conflict=True
#   Checking D3(2) against D2(6) → conflict=True
#   Total conflicts for D3 = 2: 0
#
# testing Variable D4 = 1
#   Checking D4(1) against A4(7) → conflict=True
#   Checking D4(1) against B4(2) → conflict=True
#   Checking D4(1) against C4(3) → conflict=True
#   Checking D4(1) against D1(1) → conflict=False
#   Checking D4(1) against D2(6) → conflict=True
#   Checking D4(1) against D3(2) → conflict=True
#   Total conflicts for D4 = 1: 1
#
# testing Variable D4 = 5
#   Checking D4(5) against A4(7) → conflict=True
#   Checking D4(5) against B4(2) → conflict=True
#   Checking D4(5) against C4(3) → conflict=True
#   Checking D4(5) against D1(1) → conflict=True
#   Checking D4(5) against D2(6) → conflict=True
#   Checking D4(5) against D3(2) → conflict=True
#   Total conflicts for D4 = 5: 0
#
# testing Variable D5 = 7
#   Checking D5(7) against A5(4) → conflict=True
#   Checking D5(7) against B5(8) → conflict=True
#   Checking D5(7) against C5(1) → conflict=True
#   Checking D5(7) against D1(1) → conflict=True
#   Checking D5(7) against D2(6) → conflict=True
#   Checking D5(7) against D3(2) → conflict=True
#   Checking D5(7) against D4(5) → conflict=True
#   Total conflicts for D5 = 7: 0
#
# testing Variable D6 = 3
#   Checking D6(3) against A6(9) → conflict=True
#   Checking D6(3) against B6(6) → conflict=True
#   Checking D6(3) against C6(5) → conflict=True
#   Checking D6(3) against D1(1) → conflict=True
#   Checking D6(3) against D2(6) → conflict=True
#   Checking D6(3) against D3(2) → conflict=True
#   Checking D6(3) against D4(5) → conflict=True
#   Checking D6(3) against D5(7) → conflict=True
#   Total conflicts for D6 = 3: 0
#
# testing Variable D7 = 8
#   Checking D7(8) against A7(3) → conflict=True
#   Checking D7(8) against B7(1) → conflict=True
#   Checking D7(8) against C7(9) → conflict=True
#   Checking D7(8) against D1(1) → conflict=True
#   Checking D7(8) against D2(6) → conflict=True
#   Checking D7(8) against D3(2) → conflict=True
#   Checking D7(8) against D4(5) → conflict=True
#   Checking D7(8) against D5(7) → conflict=True
#   Checking D7(8) against D6(3) → conflict=True
#   Total conflicts for D7 = 8: 0
#
# testing Variable D8 = 1
#   Checking D8(1) against A8(6) → conflict=True
#   Checking D8(1) against B8(4) → conflict=True
#   Checking D8(1) against C8(7) → conflict=True
#   Checking D8(1) against D1(1) → conflict=False
#   Checking D8(1) against D2(6) → conflict=True
#   Checking D8(1) against D3(2) → conflict=True
#   Checking D8(1) against D4(5) → conflict=True
#   Checking D8(1) against D5(7) → conflict=True
#   Checking D8(1) against D6(3) → conflict=True
#   Checking D8(1) against D7(8) → conflict=True
#   Total conflicts for D8 = 1: 1
#
# testing Variable D8 = 3
#   Checking D8(3) against A8(6) → conflict=True
#   Checking D8(3) against B8(4) → conflict=True
#   Checking D8(3) against C8(7) → conflict=True
#   Checking D8(3) against D1(1) → conflict=True
#   Checking D8(3) against D2(6) → conflict=True
#   Checking D8(3) against D3(2) → conflict=True
#   Checking D8(3) against D4(5) → conflict=True
#   Checking D8(3) against D5(7) → conflict=True
#   Checking D8(3) against D6(3) → conflict=False
#   Checking D8(3) against D7(8) → conflict=True
#   Total conflicts for D8 = 3: 1
#
# testing Variable D8 = 4
#   Checking D8(4) against A8(6) → conflict=True
#   Checking D8(4) against B8(4) → conflict=False
#   Checking D8(4) against C8(7) → conflict=True
#   Checking D8(4) against D1(1) → conflict=True
#   Checking D8(4) against D2(6) → conflict=True
#   Checking D8(4) against D3(2) → conflict=True
#   Checking D8(4) against D4(5) → conflict=True
#   Checking D8(4) against D5(7) → conflict=True
#   Checking D8(4) against D6(3) → conflict=True
#   Checking D8(4) against D7(8) → conflict=True
#   Total conflicts for D8 = 4: 1
#
# testing Variable D8 = 5
#   Checking D8(5) against A8(6) → conflict=True
#   Checking D8(5) against B8(4) → conflict=True
#   Checking D8(5) against C8(7) → conflict=True
#   Checking D8(5) against D1(1) → conflict=True
#   Checking D8(5) against D2(6) → conflict=True
#   Checking D8(5) against D3(2) → conflict=True
#   Checking D8(5) against D4(5) → conflict=False
#   Checking D8(5) against D5(7) → conflict=True
#   Checking D8(5) against D6(3) → conflict=True
#   Checking D8(5) against D7(8) → conflict=True
#   Total conflicts for D8 = 5: 1
#
# testing Variable D6 = 4
#   Checking D6(4) against A6(9) → conflict=True
#   Checking D6(4) against B6(6) → conflict=True
#   Checking D6(4) against C6(5) → conflict=True
#   Checking D6(4) against D1(1) → conflict=True
#   Checking D6(4) against D2(6) → conflict=True
#   Checking D6(4) against D3(2) → conflict=True
#   Checking D6(4) against D4(5) → conflict=True
#   Checking D6(4) against D5(7) → conflict=True
#   Total conflicts for D6 = 4: 0
#
# testing Variable D7 = 8
#   Checking D7(8) against A7(3) → conflict=True
#   Checking D7(8) against B7(1) → conflict=True
#   Checking D7(8) against C7(9) → conflict=True
#   Checking D7(8) against D1(1) → conflict=True
#   Checking D7(8) against D2(6) → conflict=True
#   Checking D7(8) against D3(2) → conflict=True
#   Checking D7(8) against D4(5) → conflict=True
#   Checking D7(8) against D5(7) → conflict=True
#   Checking D7(8) against D6(4) → conflict=True
#   Total conflicts for D7 = 8: 0
#
# testing Variable D8 = 1
#   Checking D8(1) against A8(6) → conflict=True
#   Checking D8(1) against B8(4) → conflict=True
#   Checking D8(1) against C8(7) → conflict=True
#   Checking D8(1) against D1(1) → conflict=False
#   Checking D8(1) against D2(6) → conflict=True
#   Checking D8(1) against D3(2) → conflict=True
#   Checking D8(1) against D4(5) → conflict=True
#   Checking D8(1) against D5(7) → conflict=True
#   Checking D8(1) against D6(4) → conflict=True
#   Checking D8(1) against D7(8) → conflict=True
#   Total conflicts for D8 = 1: 1
#
# testing Variable D8 = 3
#   Checking D8(3) against A8(6) → conflict=True
#   Checking D8(3) against B8(4) → conflict=True
#   Checking D8(3) against C8(7) → conflict=True
#   Checking D8(3) against D1(1) → conflict=True
#   Checking D8(3) against D2(6) → conflict=True
#   Checking D8(3) against D3(2) → conflict=True
#   Checking D8(3) against D4(5) → conflict=True
#   Checking D8(3) against D5(7) → conflict=True
#   Checking D8(3) against D6(4) → conflict=True
#   Checking D8(3) against D7(8) → conflict=True
#   Total conflicts for D8 = 3: 0
#
# testing Variable D9 = 3
#   Checking D9(3) against A9(8) → conflict=True
#   Checking D9(3) against B9(5) → conflict=True
#   Checking D9(3) against C9(2) → conflict=True
#   Checking D9(3) against D1(1) → conflict=True
#   Checking D9(3) against D2(6) → conflict=True
#   Checking D9(3) against D3(2) → conflict=True
#   Checking D9(3) against D4(5) → conflict=True
#   Checking D9(3) against D5(7) → conflict=True
#   Checking D9(3) against D6(4) → conflict=True
#   Checking D9(3) against D7(8) → conflict=True
#   Checking D9(3) against D8(3) → conflict=False
#   Total conflicts for D9 = 3: 1
#
# testing Variable D9 = 4
#   Checking D9(4) against A9(8) → conflict=True
#   Checking D9(4) against B9(5) → conflict=True
#   Checking D9(4) against C9(2) → conflict=True
#   Checking D9(4) against D1(1) → conflict=True
#   Checking D9(4) against D2(6) → conflict=True
#   Checking D9(4) against D3(2) → conflict=True
#   Checking D9(4) against D4(5) → conflict=True
#   Checking D9(4) against D5(7) → conflict=True
#   Checking D9(4) against D6(4) → conflict=False
#   Checking D9(4) against D7(8) → conflict=True
#   Checking D9(4) against D8(3) → conflict=True
#   Total conflicts for D9 = 4: 1
#
# testing Variable D9 = 6
#   Checking D9(6) against A9(8) → conflict=True
#   Checking D9(6) against B9(5) → conflict=True
#   Checking D9(6) against C9(2) → conflict=True
#   Checking D9(6) against D1(1) → conflict=True
#   Checking D9(6) against D2(6) → conflict=False
#   Checking D9(6) against D3(2) → conflict=True
#   Checking D9(6) against D4(5) → conflict=True
#   Checking D9(6) against D5(7) → conflict=True
#   Checking D9(6) against D6(4) → conflict=True
#   Checking D9(6) against D7(8) → conflict=True
#   Checking D9(6) against D8(3) → conflict=True
#   Total conflicts for D9 = 6: 1
#
# testing Variable D9 = 9
#   Checking D9(9) against A9(8) → conflict=True
#   Checking D9(9) against B9(5) → conflict=True
#   Checking D9(9) against C9(2) → conflict=True
#   Checking D9(9) against D1(1) → conflict=True
#   Checking D9(9) against D2(6) → conflict=True
#   Checking D9(9) against D3(2) → conflict=True
#   Checking D9(9) against D4(5) → conflict=True
#   Checking D9(9) against D5(7) → conflict=True
#   Checking D9(9) against D6(4) → conflict=True
#   Checking D9(9) against D7(8) → conflict=True
#   Checking D9(9) against D8(3) → conflict=True
#   Total conflicts for D9 = 9: 0
#
# testing Variable E1 = 1
#   Checking E1(1) against A1(2) → conflict=True
#   Checking E1(1) against B1(3) → conflict=True
#   Checking E1(1) against C1(4) → conflict=True
#   Checking E1(1) against D1(1) → conflict=False
#   Checking E1(1) against D2(6) → conflict=True
#   Checking E1(1) against D3(2) → conflict=True
#   Total conflicts for E1 = 1: 1
#
# testing Variable E1 = 4
#   Checking E1(4) against A1(2) → conflict=True
#   Checking E1(4) against B1(3) → conflict=True
#   Checking E1(4) against C1(4) → conflict=False
#   Checking E1(4) against D1(1) → conflict=True
#   Checking E1(4) against D2(6) → conflict=True
#   Checking E1(4) against D3(2) → conflict=True
#   Total conflicts for E1 = 4: 1
#
# testing Variable E1 = 5
#   Checking E1(5) against A1(2) → conflict=True
#   Checking E1(5) against B1(3) → conflict=True
#   Checking E1(5) against C1(4) → conflict=True
#   Checking E1(5) against D1(1) → conflict=True
#   Checking E1(5) against D2(6) → conflict=True
#   Checking E1(5) against D3(2) → conflict=True
#   Total conflicts for E1 = 5: 0
#
# testing Variable E2 = 4
#   Checking E2(4) against A2(1) → conflict=True
#   Checking E2(4) against B2(7) → conflict=True
#   Checking E2(4) against B5(8) → conflict=True
#   Checking E2(4) against C2(8) → conflict=True
#   Checking E2(4) against C3(6) → conflict=True
#   Checking E2(4) against C7(9) → conflict=True
#   Checking E2(4) against D1(1) → conflict=True
#   Checking E2(4) against D2(6) → conflict=True
#   Checking E2(4) against D3(2) → conflict=True
#   Checking E2(4) against E1(5) → conflict=True
#   Total conflicts for E2 = 4: 0
#
# testing Variable E3 = 1
#   Checking E3(1) against A3(5) → conflict=True
#   Checking E3(1) against B3(9) → conflict=True
#   Checking E3(1) against C3(6) → conflict=True
#   Checking E3(1) against D1(1) → conflict=False
#   Checking E3(1) against D2(6) → conflict=True
#   Checking E3(1) against D3(2) → conflict=True
#   Checking E3(1) against E1(5) → conflict=True
#   Checking E3(1) against E2(4) → conflict=True
#   Total conflicts for E3 = 1: 1
#
# testing Variable E3 = 3
#   Checking E3(3) against A3(5) → conflict=True
#   Checking E3(3) against B3(9) → conflict=True
#   Checking E3(3) against C3(6) → conflict=True
#   Checking E3(3) against D1(1) → conflict=True
#   Checking E3(3) against D2(6) → conflict=True
#   Checking E3(3) against D3(2) → conflict=True
#   Checking E3(3) against E1(5) → conflict=True
#   Checking E3(3) against E2(4) → conflict=True
#   Total conflicts for E3 = 3: 0
#
# testing Variable E4 = 6
#   Checking E4(6) against A4(7) → conflict=True
#   Checking E4(6) against B4(2) → conflict=True
#   Checking E4(6) against C4(3) → conflict=True
#   Checking E4(6) against D4(5) → conflict=True
#   Checking E4(6) against D5(7) → conflict=True
#   Checking E4(6) against D6(4) → conflict=True
#   Checking E4(6) against E1(5) → conflict=True
#   Checking E4(6) against E2(4) → conflict=True
#   Checking E4(6) against E3(3) → conflict=True
#   Total conflicts for E4 = 6: 0
#
# testing Variable E5 = 1
#   Checking E5(1) against A5(4) → conflict=True
#   Checking E5(1) against B5(8) → conflict=True
#   Checking E5(1) against C3(6) → conflict=True
#   Checking E5(1) against C5(1) → conflict=False
#   Checking E5(1) against C7(9) → conflict=True
#   Checking E5(1) against D4(5) → conflict=True
#   Checking E5(1) against D5(7) → conflict=True
#   Checking E5(1) against D6(4) → conflict=True
#   Checking E5(1) against E1(5) → conflict=True
#   Checking E5(1) against E2(4) → conflict=True
#   Checking E5(1) against E3(3) → conflict=True
#   Checking E5(1) against E4(6) → conflict=True
#   Total conflicts for E5 = 1: 1
#
# testing Variable E5 = 2
#   Checking E5(2) against A5(4) → conflict=True
#   Checking E5(2) against B5(8) → conflict=True
#   Checking E5(2) against C3(6) → conflict=True
#   Checking E5(2) against C5(1) → conflict=True
#   Checking E5(2) against C7(9) → conflict=True
#   Checking E5(2) against D4(5) → conflict=True
#   Checking E5(2) against D5(7) → conflict=True
#   Checking E5(2) against D6(4) → conflict=True
#   Checking E5(2) against E1(5) → conflict=True
#   Checking E5(2) against E2(4) → conflict=True
#   Checking E5(2) against E3(3) → conflict=True
#   Checking E5(2) against E4(6) → conflict=True
#   Total conflicts for E5 = 2: 0
#
# testing Variable E6 = 8
#   Checking E6(8) against A6(9) → conflict=True
#   Checking E6(8) against B6(6) → conflict=True
#   Checking E6(8) against C6(5) → conflict=True
#   Checking E6(8) against D4(5) → conflict=True
#   Checking E6(8) against D5(7) → conflict=True
#   Checking E6(8) against D6(4) → conflict=True
#   Checking E6(8) against E1(5) → conflict=True
#   Checking E6(8) against E2(4) → conflict=True
#   Checking E6(8) against E3(3) → conflict=True
#   Checking E6(8) against E4(6) → conflict=True
#   Checking E6(8) against E5(2) → conflict=True
#   Total conflicts for E6 = 8: 0
#
# testing Variable E7 = 3
#   Checking E7(3) against A7(3) → conflict=False
#   Checking E7(3) against B7(1) → conflict=True
#   Checking E7(3) against C7(9) → conflict=True
#   Checking E7(3) against D7(8) → conflict=True
#   Checking E7(3) against D8(3) → conflict=False
#   Checking E7(3) against D9(9) → conflict=True
#   Checking E7(3) against E1(5) → conflict=True
#   Checking E7(3) against E2(4) → conflict=True
#   Checking E7(3) against E3(3) → conflict=False
#   Checking E7(3) against E4(6) → conflict=True
#   Checking E7(3) against E5(2) → conflict=True
#   Checking E7(3) against E6(8) → conflict=True
#   Total conflicts for E7 = 3: 3
#
# testing Variable E7 = 4
#   Checking E7(4) against A7(3) → conflict=True
#   Checking E7(4) against B7(1) → conflict=True
#   Checking E7(4) against C7(9) → conflict=True
#   Checking E7(4) against D7(8) → conflict=True
#   Checking E7(4) against D8(3) → conflict=True
#   Checking E7(4) against D9(9) → conflict=True
#   Checking E7(4) against E1(5) → conflict=True
#   Checking E7(4) against E2(4) → conflict=False
#   Checking E7(4) against E3(3) → conflict=True
#   Checking E7(4) against E4(6) → conflict=True
#   Checking E7(4) against E5(2) → conflict=True
# ...
#   Checking H9(1) against A9(8) → conflict=True
#   Checking H9(1) against B9(5) → conflict=True
#   Checking H9(1) against C9(2) → conflict=True
#   Checking H9(1) against D9(6) → conflict=True
#   Checking H9(1) against E9(9) → conflict=True
#   Checking H9(1) against F9(4) → conflict=True
#   Checking H9(1) against G7(5) → conflict=True
#   Checking H9(1) against G8(9) → conflict=True
#   Checking H9(1) against G9(3) → conflict=True
#   Checking H9(1) against H1(9) → conflict=True
#   Checking H9(1) against H2(5) → conflict=True
#   Checking H9(1) against H3(4) → conflict=True
#   Checking H9(1) against H4(8) → conflict=True
#   Checking H9(1) against H5(3) → conflict=True
#   Checking H9(1) against H6(7) → conflict=True
#   Checking H9(1) against H7(6) → conflict=True
#   Checking H9(1) against H8(2) → conflict=True
#   Total conflicts for H9 = 1: 0
#
# testing Variable I1 = 1
#   Checking I1(1) against A1(2) → conflict=True
#   Checking I1(1) against B1(3) → conflict=True
#   Checking I1(1) against C1(4) → conflict=True
#   Checking I1(1) against D1(1) → conflict=False
#   Checking I1(1) against E1(5) → conflict=True
#   Checking I1(1) against F1(7) → conflict=True
#   Checking I1(1) against G1(8) → conflict=True
#   Checking I1(1) against G2(2) → conflict=True
#   Checking I1(1) against G3(7) → conflict=True
#   Checking I1(1) against H1(9) → conflict=True
#   Checking I1(1) against H2(5) → conflict=True
#   Checking I1(1) against H3(4) → conflict=True
#   Total conflicts for I1 = 1: 1
#
# testing Variable I1 = 5
#   Checking I1(5) against A1(2) → conflict=True
#   Checking I1(5) against B1(3) → conflict=True
#   Checking I1(5) against C1(4) → conflict=True
#   Checking I1(5) against D1(1) → conflict=True
#   Checking I1(5) against E1(5) → conflict=False
#   Checking I1(5) against F1(7) → conflict=True
#   Checking I1(5) against G1(8) → conflict=True
#   Checking I1(5) against G2(2) → conflict=True
#   Checking I1(5) against G3(7) → conflict=True
#   Checking I1(5) against H1(9) → conflict=True
#   Checking I1(5) against H2(5) → conflict=False
#   Checking I1(5) against H3(4) → conflict=True
#   Total conflicts for I1 = 5: 2
#
# testing Variable I1 = 6
#   Checking I1(6) against A1(2) → conflict=True
#   Checking I1(6) against B1(3) → conflict=True
#   Checking I1(6) against C1(4) → conflict=True
#   Checking I1(6) against D1(1) → conflict=True
#   Checking I1(6) against E1(5) → conflict=True
#   Checking I1(6) against F1(7) → conflict=True
#   Checking I1(6) against G1(8) → conflict=True
#   Checking I1(6) against G2(2) → conflict=True
#   Checking I1(6) against G3(7) → conflict=True
#   Checking I1(6) against H1(9) → conflict=True
#   Checking I1(6) against H2(5) → conflict=True
#   Checking I1(6) against H3(4) → conflict=True
#   Total conflicts for I1 = 6: 0
#
# testing Variable I2 = 3
#   Checking I2(3) against A2(1) → conflict=True
#   Checking I2(3) against B2(7) → conflict=True
#   Checking I2(3) against C2(8) → conflict=True
#   Checking I2(3) against D2(9) → conflict=True
#   Checking I2(3) against E2(4) → conflict=True
#   Checking I2(3) against F2(6) → conflict=True
#   Checking I2(3) against G1(8) → conflict=True
#   Checking I2(3) against G2(2) → conflict=True
#   Checking I2(3) against G3(7) → conflict=True
#   Checking I2(3) against H1(9) → conflict=True
#   Checking I2(3) against H2(5) → conflict=True
#   Checking I2(3) against H3(4) → conflict=True
#   Checking I2(3) against I1(6) → conflict=True
#   Total conflicts for I2 = 3: 0
#
# testing Variable I3 = 1
#   Checking I3(1) against A3(5) → conflict=True
#   Checking I3(1) against B3(9) → conflict=True
#   Checking I3(1) against C3(6) → conflict=True
#   Checking I3(1) against D3(2) → conflict=True
#   Checking I3(1) against E3(3) → conflict=True
#   Checking I3(1) against F3(8) → conflict=True
#   Checking I3(1) against G1(8) → conflict=True
#   Checking I3(1) against G2(2) → conflict=True
#   Checking I3(1) against G3(7) → conflict=True
#   Checking I3(1) against H1(9) → conflict=True
#   Checking I3(1) against H2(5) → conflict=True
#   Checking I3(1) against H3(4) → conflict=True
#   Checking I3(1) against I1(6) → conflict=True
#   Checking I3(1) against I2(3) → conflict=True
#   Total conflicts for I3 = 1: 0
#
# testing Variable I4 = 2
#   Checking I4(2) against A4(7) → conflict=True
#   Checking I4(2) against B4(2) → conflict=False
#   Checking I4(2) against C4(3) → conflict=True
#   Checking I4(2) against D4(5) → conflict=True
#   Checking I4(2) against E4(6) → conflict=True
#   Checking I4(2) against F4(1) → conflict=True
#   Checking I4(2) against G4(4) → conflict=True
#   Checking I4(2) against G5(6) → conflict=True
#   Checking I4(2) against G6(1) → conflict=True
#   Checking I4(2) against H4(8) → conflict=True
#   Checking I4(2) against H5(3) → conflict=True
#   Checking I4(2) against H6(7) → conflict=True
#   Checking I4(2) against I1(6) → conflict=True
#   Checking I4(2) against I2(3) → conflict=True
#   Checking I4(2) against I3(1) → conflict=True
#   Total conflicts for I4 = 2: 1
#
# testing Variable I4 = 5
#   Checking I4(5) against A4(7) → conflict=True
#   Checking I4(5) against B4(2) → conflict=True
#   Checking I4(5) against C4(3) → conflict=True
#   Checking I4(5) against D4(5) → conflict=False
#   Checking I4(5) against E4(6) → conflict=True
#   Checking I4(5) against F4(1) → conflict=True
#   Checking I4(5) against G4(4) → conflict=True
#   Checking I4(5) against G5(6) → conflict=True
#   Checking I4(5) against G6(1) → conflict=True
#   Checking I4(5) against H4(8) → conflict=True
#   Checking I4(5) against H5(3) → conflict=True
#   Checking I4(5) against H6(7) → conflict=True
#   Checking I4(5) against I1(6) → conflict=True
#   Checking I4(5) against I2(3) → conflict=True
#   Checking I4(5) against I3(1) → conflict=True
#   Total conflicts for I4 = 5: 1
#
# testing Variable I4 = 7
#   Checking I4(7) against A4(7) → conflict=False
#   Checking I4(7) against B4(2) → conflict=True
#   Checking I4(7) against C4(3) → conflict=True
#   Checking I4(7) against D4(5) → conflict=True
#   Checking I4(7) against E4(6) → conflict=True
#   Checking I4(7) against F4(1) → conflict=True
#   Checking I4(7) against G4(4) → conflict=True
#   Checking I4(7) against G5(6) → conflict=True
#   Checking I4(7) against G6(1) → conflict=True
#   Checking I4(7) against H4(8) → conflict=True
#   Checking I4(7) against H5(3) → conflict=True
#   Checking I4(7) against H6(7) → conflict=False
#   Checking I4(7) against I1(6) → conflict=True
#   Checking I4(7) against I2(3) → conflict=True
#   Checking I4(7) against I3(1) → conflict=True
#   Total conflicts for I4 = 7: 2
#
# testing Variable I4 = 9
#   Checking I4(9) against A4(7) → conflict=True
#   Checking I4(9) against B4(2) → conflict=True
#   Checking I4(9) against C4(3) → conflict=True
#   Checking I4(9) against D4(5) → conflict=True
#   Checking I4(9) against E4(6) → conflict=True
#   Checking I4(9) against F4(1) → conflict=True
#   Checking I4(9) against G4(4) → conflict=True
#   Checking I4(9) against G5(6) → conflict=True
#   Checking I4(9) against G6(1) → conflict=True
#   Checking I4(9) against H4(8) → conflict=True
#   Checking I4(9) against H5(3) → conflict=True
#   Checking I4(9) against H6(7) → conflict=True
#   Checking I4(9) against I1(6) → conflict=True
#   Checking I4(9) against I2(3) → conflict=True
#   Checking I4(9) against I3(1) → conflict=True
#   Total conflicts for I4 = 9: 0
#
# testing Variable I5 = 2
#   Checking I5(2) against A5(4) → conflict=True
#   Checking I5(2) against B5(8) → conflict=True
#   Checking I5(2) against C5(1) → conflict=True
#   Checking I5(2) against D5(7) → conflict=True
#   Checking I5(2) against E5(2) → conflict=False
#   Checking I5(2) against F5(9) → conflict=True
#   Checking I5(2) against G4(4) → conflict=True
#   Checking I5(2) against G5(6) → conflict=True
#   Checking I5(2) against G6(1) → conflict=True
#   Checking I5(2) against H4(8) → conflict=True
#   Checking I5(2) against H5(3) → conflict=True
#   Checking I5(2) against H6(7) → conflict=True
#   Checking I5(2) against I1(6) → conflict=True
#   Checking I5(2) against I2(3) → conflict=True
#   Checking I5(2) against I3(1) → conflict=True
#   Checking I5(2) against I4(9) → conflict=True
#   Total conflicts for I5 = 2: 1
#
# testing Variable I5 = 5
#   Checking I5(5) against A5(4) → conflict=True
#   Checking I5(5) against B5(8) → conflict=True
#   Checking I5(5) against C5(1) → conflict=True
#   Checking I5(5) against D5(7) → conflict=True
#   Checking I5(5) against E5(2) → conflict=True
#   Checking I5(5) against F5(9) → conflict=True
#   Checking I5(5) against G4(4) → conflict=True
#   Checking I5(5) against G5(6) → conflict=True
#   Checking I5(5) against G6(1) → conflict=True
#   Checking I5(5) against H4(8) → conflict=True
#   Checking I5(5) against H5(3) → conflict=True
#   Checking I5(5) against H6(7) → conflict=True
#   Checking I5(5) against I1(6) → conflict=True
#   Checking I5(5) against I2(3) → conflict=True
#   Checking I5(5) against I3(1) → conflict=True
#   Checking I5(5) against I4(9) → conflict=True
#   Total conflicts for I5 = 5: 0
#
# testing Variable I6 = 2
#   Checking I6(2) against A6(9) → conflict=True
#   Checking I6(2) against B6(6) → conflict=True
#   Checking I6(2) against C6(5) → conflict=True
#   Checking I6(2) against D6(4) → conflict=True
#   Checking I6(2) against E6(8) → conflict=True
#   Checking I6(2) against F6(3) → conflict=True
#   Checking I6(2) against G4(4) → conflict=True
#   Checking I6(2) against G5(6) → conflict=True
#   Checking I6(2) against G6(1) → conflict=True
#   Checking I6(2) against H4(8) → conflict=True
#   Checking I6(2) against H5(3) → conflict=True
#   Checking I6(2) against H6(7) → conflict=True
#   Checking I6(2) against I1(6) → conflict=True
#   Checking I6(2) against I2(3) → conflict=True
#   Checking I6(2) against I3(1) → conflict=True
#   Checking I6(2) against I4(9) → conflict=True
#   Checking I6(2) against I5(5) → conflict=True
#   Total conflicts for I6 = 2: 0
#
# testing Variable I7 = 4
#   Checking I7(4) against A7(3) → conflict=True
#   Checking I7(4) against B7(1) → conflict=True
#   Checking I7(4) against C7(9) → conflict=True
#   Checking I7(4) against D7(8) → conflict=True
#   Checking I7(4) against E7(7) → conflict=True
#   Checking I7(4) against F7(2) → conflict=True
#   Checking I7(4) against G7(5) → conflict=True
#   Checking I7(4) against G8(9) → conflict=True
#   Checking I7(4) against G9(3) → conflict=True
#   Checking I7(4) against H7(6) → conflict=True
#   Checking I7(4) against H8(2) → conflict=True
#   Checking I7(4) against H9(1) → conflict=True
#   Checking I7(4) against I1(6) → conflict=True
#   Checking I7(4) against I2(3) → conflict=True
#   Checking I7(4) against I3(1) → conflict=True
#   Checking I7(4) against I4(9) → conflict=True
#   Checking I7(4) against I5(5) → conflict=True
#   Checking I7(4) against I6(2) → conflict=True
#   Total conflicts for I7 = 4: 0
#
# testing Variable I8 = 8
#   Checking I8(8) against A8(6) → conflict=True
#   Checking I8(8) against B8(4) → conflict=True
#   Checking I8(8) against C8(7) → conflict=True
#   Checking I8(8) against D8(3) → conflict=True
#   Checking I8(8) against E8(1) → conflict=True
#   Checking I8(8) against F8(5) → conflict=True
#   Checking I8(8) against G7(5) → conflict=True
#   Checking I8(8) against G8(9) → conflict=True
#   Checking I8(8) against G9(3) → conflict=True
#   Checking I8(8) against H7(6) → conflict=True
#   Checking I8(8) against H8(2) → conflict=True
#   Checking I8(8) against H9(1) → conflict=True
#   Checking I8(8) against I1(6) → conflict=True
#   Checking I8(8) against I2(3) → conflict=True
#   Checking I8(8) against I3(1) → conflict=True
#   Checking I8(8) against I4(9) → conflict=True
#   Checking I8(8) against I5(5) → conflict=True
#   Checking I8(8) against I6(2) → conflict=True
#   Checking I8(8) against I7(4) → conflict=True
#   Total conflicts for I8 = 8: 0
#
# testing Variable I9 = 2
#   Checking I9(2) against A9(8) → conflict=True
#   Checking I9(2) against B9(5) → conflict=True
#   Checking I9(2) against C9(2) → conflict=False
#   Checking I9(2) against D9(6) → conflict=True
#   Checking I9(2) against E9(9) → conflict=True
#   Checking I9(2) against F9(4) → conflict=True
#   Checking I9(2) against G7(5) → conflict=True
#   Checking I9(2) against G8(9) → conflict=True
#   Checking I9(2) against G9(3) → conflict=True
#   Checking I9(2) against H7(6) → conflict=True
#   Checking I9(2) against H8(2) → conflict=False
#   Checking I9(2) against H9(1) → conflict=True
#   Checking I9(2) against I1(6) → conflict=True
#   Checking I9(2) against I2(3) → conflict=True
#   Checking I9(2) against I3(1) → conflict=True
#   Checking I9(2) against I4(9) → conflict=True
#   Checking I9(2) against I5(5) → conflict=True
#   Checking I9(2) against I6(2) → conflict=False
#   Checking I9(2) against I7(4) → conflict=True
#   Checking I9(2) against I8(8) → conflict=True
#   Total conflicts for I9 = 2: 3
#
# testing Variable I9 = 4
#   Checking I9(4) against A9(8) → conflict=True
#   Checking I9(4) against B9(5) → conflict=True
#   Checking I9(4) against C9(2) → conflict=True
#   Checking I9(4) against D9(6) → conflict=True
#   Checking I9(4) against E9(9) → conflict=True
#   Checking I9(4) against F9(4) → conflict=False
#   Checking I9(4) against G7(5) → conflict=True
#   Checking I9(4) against G8(9) → conflict=True
#   Checking I9(4) against G9(3) → conflict=True
#   Checking I9(4) against H7(6) → conflict=True
#   Checking I9(4) against H8(2) → conflict=True
#   Checking I9(4) against H9(1) → conflict=True
#   Checking I9(4) against I1(6) → conflict=True
#   Checking I9(4) against I2(3) → conflict=True
#   Checking I9(4) against I3(1) → conflict=True
#   Checking I9(4) against I4(9) → conflict=True
#   Checking I9(4) against I5(5) → conflict=True
#   Checking I9(4) against I6(2) → conflict=True
#   Checking I9(4) against I7(4) → conflict=False
#   Checking I9(4) against I8(8) → conflict=True
#   Total conflicts for I9 = 4: 2
#
# testing Variable I9 = 7
#   Checking I9(7) against A9(8) → conflict=True
#   Checking I9(7) against B9(5) → conflict=True
#   Checking I9(7) against C9(2) → conflict=True
#   Checking I9(7) against D9(6) → conflict=True
#   Checking I9(7) against E9(9) → conflict=True
#   Checking I9(7) against F9(4) → conflict=True
#   Checking I9(7) against G7(5) → conflict=True
#   Checking I9(7) against G8(9) → conflict=True
#   Checking I9(7) against G9(3) → conflict=True
#   Checking I9(7) against H7(6) → conflict=True
#   Checking I9(7) against H8(2) → conflict=True
#   Checking I9(7) against H9(1) → conflict=True
#   Checking I9(7) against I1(6) → conflict=True
#   Checking I9(7) against I2(3) → conflict=True
#   Checking I9(7) against I3(1) → conflict=True
#   Checking I9(7) against I4(9) → conflict=True
#   Checking I9(7) against I5(5) → conflict=True
#   Checking I9(7) against I6(2) → conflict=True
#   Checking I9(7) against I7(4) → conflict=True
#   Checking I9(7) against I8(8) → conflict=True
#   Total conflicts for I9 = 7: 0
# {'A1': 2, 'A2': 1, 'A3': 5, 'A4': 7, 'A5': 4, 'A6': 9, 'A7': 3, 'A8': 6, 'A9': 8, 'B1': 3, 'B2': 7, 'B3': 9, 'B4': 2, 'B5': 8, 'B6': 6, 'B7': 1, 'B8': 4, 'B9': 5, 'C1': 4, 'C2': 8, 'C3': 6, 'C4': 3, 'C5': 1, 'C6': 5, 'C7': 9, 'C8': 7, 'C9': 2, 'D1': 1, 'D2': 9, 'D3': 2, 'D4': 5, 'D5': 7, 'D6': 4, 'D7': 8, 'D8': 3, 'D9': 6, 'E1': 5, 'E2': 4, 'E3': 3, 'E4': 6, 'E5': 2, 'E6': 8, 'E7': 7, 'E8': 1, 'E9': 9, 'F1': 7, 'F2': 6, 'F3': 8, 'F4': 1, 'F5': 9, 'F6': 3, 'F7': 2, 'F8': 5, 'F9': 4, 'G1': 8, 'G2': 2, 'G3': 7, 'G4': 4, 'G5': 6, 'G6': 1, 'G7': 5, 'G8': 9, 'G9': 3, 'H1': 9, 'H2': 5, 'H3': 4, 'H4': 8, 'H5': 3, 'H6': 7, 'H7': 6, 'H8': 2, 'H9': 1, 'I1': 6, 'I2': 3, 'I3': 1, 'I4': 9, 'I5': 5, 'I6': 2, 'I7': 4, 'I8': 8, 'I9': 7}
# {'A1': 2,
#  'A2': 1,
#  'A3': 5,
#  'A4': 7,
#  'A5': 4,
#  'A6': 9,
#  'A7': 3,
#  'A8': 6,
#  'A9': 8,
#  'B1': 3,
#  'B2': 7,
#  'B3': 9,
#  'B4': 2,
#  'B5': 8,
#  'B6': 6,
#  'B7': 1,
#  'B8': 4,
#  'B9': 5,
#  'C1': 4,
#  'C2': 8,
#  'C3': 6,
#  'C4': 3,
#  'C5': 1,
#  'C6': 5,
#  'C7': 9,
#  'C8': 7,
#  'C9': 2,
#  'D1': 1,
#  'D2': 9,
#  'D3': 2,
#  'D4': 5,
#  'D5': 7,
#  'D6': 4,
#  'D7': 8,
#  'D8': 3,
#  'D9': 6,
#  'E1': 5,
#  'E2': 4,
#  'E3': 3,
#  'E4': 6,
#  'E5': 2,
#  'E6': 8,
#  'E7': 7,
#  'E8': 1,
#  'E9': 9,
#  'F1': 7,
#  'F2': 6,
#  'F3': 8,
#  'F4': 1,
#  'F5': 9,
#  'F6': 3,
#  'F7': 2,
#  'F8': 5,
#  'F9': 4,
#  'G1': 8,
#  'G2': 2,
#  'G3': 7,
#  'G4': 4,
#  'G5': 6,
#  'G6': 1,
#  'G7': 5,
#  'G8': 9,
#  'G9': 3,
#  'H1': 9,
#  'H2': 5,
#  'H3': 4,
#  'H4': 8,
#  'H5': 3,
#  'H6': 7,
#  'H7': 6,
#  'H8': 2,
#  'H9': 1,
#  'I1': 6,
#  'I2': 3,
#  'I3': 1,
#  'I4': 9,
#  'I5': 5,
#  'I6': 2,
#  'I7': 4,
#  'I8': 8,
#  'I9': 7}
