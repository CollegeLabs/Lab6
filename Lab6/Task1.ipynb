# %%
from src.utils import parse_neighbors
from src.CSPclass import CSPBasic
from src.algorithms import AC3

# %%
neighbors = parse_neighbors('A: B; B: A; A: C; C: A; B: D; D: B; D: E; E: D; B: C; C: B; C: F; F: C; F: G; G: F')
domains = { 'A': ["Mon", "Tue", "Wed"], 
            'B': ["Tue"],
            'C': ["Mon", "Tue", "Wed"],
            'D': ["Mon", "Tue", "Wed"],
            'E': ["Mon", "Tue", "Wed"],
            'F': ["Wed"],
            'G': ["Mon", "Tue", "Wed"],}
constraints = lambda X, x, Y, y: x==y
task1CSP = CSPBasic(variables=None, neighbors=neighbors, domains=domains, constraints=constraints)
