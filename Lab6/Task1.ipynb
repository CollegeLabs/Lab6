# %%
from pyvis.network import Network
from src.utils import parse_neighbors
from src.CSPclass import *
from src.algorithms import AC3
import streamlit as st

# %%
'''
putting these here for reference
A = Algorithms I
B = Intro to File and Database Management
C = Practical Programming Methodology
D = Computer Organization and Arcitecture
E = Linear Algebra I
F = Intro to Applied Statistics
G = Operating Systems
'''
titles = ["Algorithms I",
          "Intro to File and Database Management",
          "Practical Programming Methodology",
          "Computer Organization and Arcitecture",
          "Linear Algebra I",
          "Intro to Applied Statistics",
          "Operating Systems"]
#variables = ["A", "B", "C", "D", "E", "F", "G"] #I don't actually put this into the CSP apparently
neighbors = parse_neighbors('A: B; A: C; B: D; D: E; B: C; C: E; C: F; F: G')
domains = { 'A': ["Mon", "Tue", "Wed"], 
            'B': ["Tue"],
            'C': ["Mon", "Tue", "Wed"],
            'D': ["Mon", "Tue", "Wed"],
            'E': ["Mon", "Tue", "Wed"],
            'F': ["Wed"],
            'G': ["Mon", "Tue", "Wed"],}
constraints = lambda X, x, Y, y: x!=y
task1CSP = CSPBasic(variables=None, domains=domains, neighbors=neighbors, constraints=constraints)

# %%
net_task1 = Network( heading="Lab6. Task 1",
                bgcolor ="#242020",
                font_color = "white",
                height = "750px",
                width = "100%"
)

# %%
nodes=task1CSP.domains
sizes=10*len(nodes)
nodeTitles=[]

for node in nodes:
    nodeTitles.append(nodes[node])
nodes=list(nodes)

# %%
i=0 #tmp variable for add_node
for node in nodes:
    net_task1.add_node(node, label=titles[i], title=", ".join(nodeTitles[i]))
    i+=1

# %%
for nodeFrom in task1CSP.neighbors.keys():
    for nodeTo in task1CSP.neighbors[nodeFrom]:
        net_task1.add_edge(nodeFrom, nodeTo, size=sizes)#, title=nodeTitles)

# %%
net_task1.show("Task1Graph.html", notebook=False)
# Out:
# Task1Graph.html

# %%
AC3(task1CSP)
# Out:
# Initial queue:
# ('A', 'B') ('A', 'C')
# ('B', 'A') ('B', 'D') ('B', 'C')
# ('C', 'A') ('C', 'B') ('C', 'E') ('C', 'F')
# ('D', 'B') ('D', 'E')
# ('E', 'D') ('E', 'C')
# ('F', 'C') ('F', 'G')
# ('G', 'F')
# Arc ('A', 'B') is cheking
# The val Tue was deleted from A domain
# Queue: [('A', 'C'), ('B', 'A'), ('B', 'D'), ('B', 'C'), ('C', 'A'), ('C', 'B'), ('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A')]
# Arc ('A', 'C') is cheking
# Queue: [('B', 'A'), ('B', 'D'), ('B', 'C'), ('C', 'A'), ('C', 'B'), ('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A')]
# Arc ('B', 'A') is cheking
# Queue: [('B', 'D'), ('B', 'C'), ('C', 'A'), ('C', 'B'), ('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A')]
# Arc ('B', 'D') is cheking
# Queue: [('B', 'C'), ('C', 'A'), ('C', 'B'), ('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A')]
# Arc ('B', 'C') is cheking
# Queue: [('C', 'A'), ('C', 'B'), ('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A')]
# Arc ('C', 'A') is cheking
# Queue: [('C', 'B'), ('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A')]
# Arc ('C', 'B') is cheking
# The val Tue was deleted from C domain
# Queue: [('C', 'E'), ('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C')]
# Arc ('C', 'E') is cheking
# Queue: [('C', 'F'), ('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C')]
# Arc ('C', 'F') is cheking
# The val Wed was deleted from C domain
# Queue: [('D', 'B'), ('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C')]
# Arc ('D', 'B') is cheking
# The val Tue was deleted from D domain
# Queue: [('D', 'E'), ('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D')]
# Arc ('D', 'E') is cheking
# Queue: [('E', 'D'), ('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D')]
# Arc ('E', 'D') is cheking
# Queue: [('E', 'C'), ('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D')]
# Arc ('E', 'C') is cheking
# The val Mon was deleted from E domain
# Queue: [('F', 'C'), ('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E')]
# Arc ('F', 'C') is cheking
# Queue: [('F', 'G'), ('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E')]
# Arc ('F', 'G') is cheking
# Queue: [('G', 'F'), ('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E')]
# Arc ('G', 'F') is cheking
# The val Wed was deleted from G domain
# Queue: [('C', 'A'), ('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E')]
# Arc ('C', 'A') is cheking
# Queue: [('A', 'C'), ('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E')]
# Arc ('A', 'C') is cheking
# The val Mon was deleted from A domain
# Queue: [('E', 'C'), ('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E'), ('B', 'A')]
# Arc ('E', 'C') is cheking
# Queue: [('F', 'C'), ('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E'), ('B', 'A')]
# Arc ('F', 'C') is cheking
# Queue: [('A', 'C'), ('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E'), ('B', 'A')]
# Arc ('A', 'C') is cheking
# Queue: [('B', 'C'), ('E', 'C'), ('E', 'D'), ('D', 'E'), ('B', 'A')]
# Arc ('B', 'C') is cheking
# Queue: [('E', 'C'), ('E', 'D'), ('D', 'E'), ('B', 'A')]
# Arc ('E', 'C') is cheking
# Queue: [('E', 'D'), ('D', 'E'), ('B', 'A')]
# Arc ('E', 'D') is cheking
# Queue: [('D', 'E'), ('B', 'A')]
# Arc ('D', 'E') is cheking
# Queue: [('B', 'A')]
# Arc ('B', 'A') is cheking
# Queue: []
# (True, 55)

# %%
net_task1_AC3 = Network( heading="Lab6. Task 1 after AC3",
                bgcolor ="#242020",
                font_color = "white",
                height = "750px",
                width = "100%"
)

# %%
nodes=task1CSP.curr_domains
sizes=10*len(nodes)
nodeTitles=[]

for node in nodes:
    nodeTitles.append(nodes[node])
nodes=list(nodes)

# %%
i=0 #tmp variable for add_node
for node in nodes:
    net_task1_AC3.add_node(node, label=titles[i], title=", ".join(nodeTitles[i]))
    i+=1

# %%
for nodeFrom in task1CSP.neighbors.keys():
    for nodeTo in task1CSP.neighbors[nodeFrom]:
        net_task1_AC3.add_edge(nodeFrom, nodeTo, size=sizes)#, title=nodeTitles)

# %%
net_task1_AC3.show("Task1GraphAC3.html", notebook=False)
# Out:
# Task1GraphAC3.html
